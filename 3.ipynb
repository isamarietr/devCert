# %% [markdown]
# <If there are any questions, reach out via isa.torres@mongodb.com>
#
# [Find Me on LinkedIn!](https://www.linkedin.com/in/isatorres/)
#
# # Welcome to Session 3: Indexes and Aggregations
# ## Aggregations
#
# In our last session we talked in depth about `MQL`, Mongo Query Language, which is the primary way to perform reads, writes, updates, etc, against data in MongoDB. However, there is sometimes a requirement to read data (or manipulate data) in more advanced ways than `MQL`
#
# To accomplish this, MongoDB has another query syntax called the `Aggregation Framework`. It generally follows the following syntax:
#
# `db.collection.aggregate([aggregation_stages])`
#
# As an argument, the `aggregate` accepts an array of `stages`. The output of 1 stage becomes the input to the next stage, so a developer is able to massage the data in unique ways.
#
# One limitation of the aggregation stage is no stage can have more than 100mb of data (allowDiskUse to get around this)
#
# **similar to how knowing / remembering query operators, it is important on the test to have a level of knowledge regarding the most common stages**
#
# Let's take a look at some basic aggregations, then we can do a deeper dive into the specific stages

# %%
# First Let's connect to the DB
# Variables
mongoDB_username = ""
mongoDB_password = ""
mongoDB_connection_string = ""

# %%
aggString = "db.movies.aggregate([{\\$match:{year:1991}}])"

print(aggString.replace("\\", ""))
print("")

# !mongosh {mongoDB_connection_string} --quiet  --username {mongoDB_username} -p {mongoDB_password} \
--eval "use sample_mflix" \
--eval """{aggString}"""
# Out:
# db.movies.aggregate([{$match:{year:1991}}])
#
#  [
#   {
#     _id: ObjectId('573a1398f29313caabcead6a'),
#     plot: 'A septuagenarian couple are attracted to each other in a retirement home but find the institution and their fellow patients frown on their relationship.',
#     genres: [ 'Drama', 'Romance' ],
#     runtime: 110,
#     cast: [
#       'Ingrid Thulin',
#       'Dado Ruspoli',
#       'Enzo Cannavale',
#       'Nuccia Fumo'
#     ],
#     title: 'The House of Smiles',
#     fullplot: 'Adelina, a former "Miss Smiles" beauty queen, is a resident at a senior citizen retirement home. Her joie de vie and unfaded beauty make her attractive to the male residents, especially Andrea, a dapper and charming but married septuagenarian. Their initial mutual attraction evolves into physical desire, but their families and the conservative culture of the institution conspire against their consummating their love.',
#     languages: [ 'Italian', 'French' ],
#     released: ISODate('1991-03-01T00:00:00.000Z'),
#     directors: [ 'Marco Ferreri' ],
#     writers: [ 'Liliane Betti', 'Marco Ferreri', 'Antonino Marino' ],
#     awards: { wins: 1, nominations: 7, text: '1 win & 7 nominations.' },
#     lastupdated: '2015-08-13 00:06:59.537000000',
#     year: 1991,
#     imdb: { rating: 6.6, votes: 133, id: 94841 },
#     countries: [ 'Italy' ],
#     type: 'movie',
#     tomatoes: {
#       viewer: { rating: 3, numReviews: 55, meter: 75 },
#       dvd: ISODate('2008-08-19T00:00:00.000Z'),
#       lastUpdated: ISODate('2015-05-26T18:10:45.000Z')
#     },
#     num_mflix_comments: 0
#   },
#   {
#     _id: ObjectId('573a1398f29313caabcebadc'),
#     plot: 'Tromatic Super Heroine Susan Morris has to learn to fend for herself when she decides to escape from the urban jungle. While looking for a charming house in the country, she falls into the ...',
#     genres: [ 'Action', 'Comedy' ],
#     runtime: 81,
#     cast: [
#       'Debra Sweaney',
#       'Brian Oldfield',
#       'Sean P. Donahue',
#       'Mike Donahue'
#     ],
#     title: 'They Call Me Macho Woman!',
#     fullplot: 'Tromatic Super Heroine Susan Morris has to learn to fend for herself when she decides to escape from the urban jungle. While looking for a charming house in the country, she falls into the clutches of a band of brawny brutes - Mongo and his crew of corporate cretins. A once sweet working girl from the city, Susan is pushed to her limits and becomes a fearsome female warrior. She escapes imprisonment from the gang and, craving revenge, metamorphosizes into a heroic woodland creature. Armed with instruments of steel and skills derived from primitive survival instincts, she repels the evil onslaught. Macho Woman has arrived!',
#     languages: [ 'English' ],
#     released: ISODate('1991-02-01T00:00:00.000Z'),
#     directors: [ 'Patrick G. Donahue' ],
#     writers: [ 'Patrick G. Donahue' ],
#     awards: { wins: 0, nominations: 1, text: '1 nomination.' },
#     lastupdated: '2015-05-22 10:56:01.243000000',
#     year: 1991,
#     imdb: { rating: 4.1, votes: 100, id: 98467 },
#     countries: [ 'USA' ],
#     type: 'movie',
#     tomatoes: {
#       viewer: { rating: 2.5, numReviews: 76, meter: 20 },
#       dvd: ISODate('2005-12-06T00:00:00.000Z'),
#       lastUpdated: ISODate('2015-09-13T18:13:21.000Z')
#     },
#     num_mflix_comments: 0
#   },
#   {
#     _id: ObjectId('573a1398f29313caabcebc97'),
#     plot: 'A female police detective investigates a series of serial murders while dealing with sexist hostility from her male comrades.',
#     genres: [ 'Crime', 'Drama', 'Mystery' ],
#     runtime: 207,
#     cast: [ 'Helen Mirren', 'Tom Bell', 'John Benfield', 'Jack Ellis' ],
#     num_mflix_comments: 1,
#     poster: 'https://m.media-amazon.com/images/M/MV5BMTIzNDI3NzAxM15BMl5BanBnXkFtZTcwNzM0NzQyMQ@@._V1_SY1000_SX677_AL_.jpg',
#     title: 'Prime Suspect',
#     fullplot: "DCI Jane Tennison has been passed over time and again to lead a murder investigation, so when one of her fellow DCIs has a heart attack just before he's ready to charge their prime suspect, Jane sees her chance to lead a murder investigation. But the murder squad she takes over is hostile to her, the men upstairs are eager to pull the plug on her investigation, her personal relationships suffer from her obsession with work, and the prime suspect remains elusive. Jane has her work cut out for her as she and her team work their way through computer data trails, legwork, intuitive leaps, chases, arrests, and confessions to find the killer.",
#     languages: [ 'English' ],
#     released: ISODate('1992-01-23T00:00:00.000Z'),
#     awards: { wins: 12, nominations: 6, text: '12 wins & 6 nominations.' },
#     lastupdated: '2015-08-22 01:11:08.593000000',
#     year: 1991,
#     imdb: { rating: 8.5, votes: 3773, id: 98898 },
#     countries: [ 'UK' ],
#     type: 'series',
#     tomatoes: {
#       viewer: { rating: 3.6, numReviews: 103, meter: 78 },
#       dvd: ISODate('2010-01-25T00:00:00.000Z'),
#       lastUpdated: ISODate('2015-09-13T17:00:53.000Z')
#     }
#   },
#   {
#     _id: ObjectId('573a1398f29313caabcebdf2'),
#     plot: 'Over more than thirty years, a department of the Condesa in Mexico City, is the setting in which they are carried out ten stories, mixed, form one whose only constant is the rupture. The ...',
#     genres: [ 'Drama' ],
#     runtime: 87,
#     cast: [
#       'Gabriela Roel',
#       'Arcelia Ramèrez',
#       'Verènica Merchant',
#       'Roberto Sosa'
#     ],
#     num_mflix_comments: 0,
#     title: 'City of the Blind',
#     fullplot: 'Over more than thirty years, a department of the Condesa in Mexico City, is the setting in which they are carried out ten stories, mixed, form one whose only constant is the rupture. The passage of time and the outside world only guess through the windows and objects that come with the characters. The set is a great solitude, possible in a city of the blind.',
#     languages: [ 'Spanish' ],
#     released: ISODate('1991-10-31T00:00:00.000Z'),
#     directors: [ 'Alberto Cortès' ],
#     writers: [
#       'Josè Agustèn',
#       'Hernann Bellinghaussen',
#       'Alberto Cortès',
#       'Marcela Fuentes-Berain',
#       'Paz Alicia Garciadiego',
#       'Silvia Tomasa Rivera'
#     ],
#     awards: { wins: 3, nominations: 2, text: '3 wins & 2 nominations.' },
#     lastupdated: '2015-06-04 00:55:24.303000000',
#     year: 1991,
#     imdb: { rating: 6.6, votes: 75, id: 99274 },
#     countries: [ 'Mexico' ],
#     type: 'movie',
#     tomatoes: {
#       viewer: { rating: 3, numReviews: 27, meter: 50 },
#       dvd: ISODate('2008-05-20T00:00:00.000Z'),
#       lastUpdated: ISODate('2015-07-02T19:14:26.000Z')
#     }
#   },
#   {
#     _id: ObjectId('573a1398f29313caabcebf0b'),
#     plot: 'Agent Jackie is hired to find WWII Nazi gold hidden in the Sahara desert. He teams up with three bundling women (the 3 stooges?) who are all connected in some way. However a team of ...',
#     genres: [ 'Action', 'Adventure', 'Comedy' ],
#     runtime: 80,
#     rated: 'PG-13',
#     cast: [ 'Jackie Chan', "Carol 'Do Do' Cheng", 'Eva Cobo', 'Shèko Ikeda' ],
#     poster: 'https://m.media-amazon.com/images/M/MV5BNjEyMTk4ZDgtNjUyZi00OTg0LWFkMWEtNjk0ZWE5N2QwMmZmXkEyXkFqcGdeQXVyNjU5MjcxOTg@._V1_SY1000_SX677_AL_.jpg',
#     title: 'Armour of God 2: Operation Condor',
#     fullplot: 'Agent Jackie is hired to find WWII Nazi gold hidden in the Sahara desert. He teams up with three bundling women (the 3 stooges?) who are all connected in some way. However a team of mercenries have ideas on the ownership of the gold. A battle / chase ensues as to who gets there first. Lots of choregraphed Kung-Fu and quirky Chan humour.',
#     languages: [ 'Cantonese' ],
#     released: ISODate('1997-07-18T00:00:00.000Z'),
#     directors: [ 'Jackie Chan' ],
#     writers: [ 'Jackie Chan', 'Edward Tang' ],
#     awards: { wins: 0, nominations: 1, text: '1 nomination.' },
#     lastupdated: '2015-09-02 00:24:33.507000000',
#     year: 1991,
#     imdb: { rating: 7.2, votes: 12598, id: 99558 },
#     countries: [ 'Hong Kong' ],
#     type: 'movie',
#     tomatoes: {
#       viewer: { rating: 3.2, numReviews: 17448, meter: 66 },
#       dvd: ISODate('1999-09-14T00:00:00.000Z'),
#       critic: { rating: 6.4, numReviews: 33, meter: 70 },
#       lastUpdated: ISODate('2015-08-25T18:56:21.000Z'),
#       rotten: 10,
#       production: 'Miramax',
#       fresh: 23
#     },
#     num_mflix_comments: 0
#   },
#   {
#     _id: ObjectId('573a1399f29313caabcec20a'),
#     plot: 'A shy young man with a passion for opera has his world turned upside down by a con artist who really does have a heart of gold.',
#     genres: [ 'Comedy' ],
#     runtime: 107,
#     rated: 'R',
#     cast: [
#       'Robbie Coltrane',
#       'Michael Riley',
#       'Deborah Duchene',
#       'Eugene Lipinski'
#     ],
#     num_mflix_comments: 0,
#     poster: 'https://m.media-amazon.com/images/M/MV5BZDU1YzBjNjQtNGNmNi00OTQ4LThiMDktMTlmN2Y2NDc0MjEyXkEyXkFqcGdeQXVyNzM0MDQ1Mw@@._V1_SY1000_SX677_AL_.jpg',
#     title: 'Perfectly Normal',
#     fullplot: 'A shy young man with a passion for opera has his world turned upside down by a con artist who really does have a heart of gold.',
#     languages: [ 'English' ],
#     released: ISODate('1991-04-01T00:00:00.000Z'),
#     directors: [ 'Yves Simoneau' ],
#     writers: [
#       'Eugene Lipinski (screenplay)',
#       'Eugene Lipinski (story)',
#       'Paul Quarrington'
#     ],
#     awards: { wins: 1, nominations: 3, text: '1 win & 3 nominations.' },
#     lastupdated: '2015-04-24 00:19:25.690000000',
#     year: 1991,
#     imdb: { rating: 6.4, votes: 249, id: 100347 },
#     countries: [ 'UK', 'Canada' ],
#     type: 'movie',
#     tomatoes: {
#       viewer: { rating: 3.6, numReviews: 72, meter: 100 },
#       dvd: ISODate('1991-07-25T00:00:00.000Z'),
#       lastUpdated: ISODate('2015-07-02T19:29:22.000Z')
#     }
#   },
#   {
#     _id: ObjectId('573a1399f29313caabcec22b'),
#     plot: 'It is the time of the Spanish Inquisition. Maria does not like what is going on during the "Auto De Fe". When she speaks out, she is arrested and accused of being a witch. Torquemada has ...',
#     genres: [ 'Horror' ],
#     runtime: 97,
#     rated: 'R',
#     cast: [
#       'Lance Henriksen',
#       'Stephen Lee',
#       'William J. Norris',
#       'Mark Margolis'
#     ],
#     num_mflix_comments: 1,
#     poster: 'https://m.media-amazon.com/images/M/MV5BMWZiMjM4YzktODNhMS00YTNjLWEzNmItMWI0MWUyZWRkMTI2XkEyXkFqcGdeQXVyMTQxNzMzNDI@._V1_SY1000_SX677_AL_.jpg',
#     title: 'The Pit and the Pendulum',
#     fullplot: 'It is the time of the Spanish Inquisition. Maria does not like what is going on during the "Auto De Fe". When she speaks out, she is arrested and accused of being a witch. Torquemada has plans for her! He orders her tortured, and her tongue to be cut out. Her husband attempts to free her...',
#     languages: [ 'English' ],
#     released: ISODate('1991-06-27T00:00:00.000Z'),
#     directors: [ 'Stuart Gordon' ],
#     writers: [ 'Edgar Allan Poe (story)', 'Dennis Paoli' ],
#     awards: { wins: 1, nominations: 3, text: '1 win & 3 nominations.' },
#     lastupdated: '2015-09-16 08:12:26.737000000',
#     year: 1991,
#     imdb: { rating: 6.2, votes: 2636, id: 100369 },
#     countries: [ 'USA' ],
#     type: 'movie',
#     tomatoes: {
#       viewer: { rating: 3, numReviews: 2215, meter: 40 },
#       dvd: ISODate('2000-03-14T00:00:00.000Z'),
#       critic: { rating: 6.1, numReviews: 9, meter: 56 },
#       lastUpdated: ISODate('2015-09-03T18:19:34.000Z'),
#       rotten: 4,
#       production: 'MGM',
#       fresh: 5
#     }
#   },
#   {
#     _id: ObjectId('573a1399f29313caabcec3a5'),
#     plot: "In 1880's China, young Lalu is sold into marriage by her impoverished father. Rather than becoming a bride, Lalu ends up in an Idaho gold-mining town, the property of a saloon owner who ...",
#     genres: [ 'Romance', 'Western' ],
#     runtime: 105,
#     rated: 'PG-13',
#     cast: [
#       'Rosalind Chao',
#       'Chris Cooper',
#       'Michael Paul Chan',
#       'Dennis Dun'
#     ],
#     num_mflix_comments: 0,
#     poster: 'https://m.media-amazon.com/images/M/MV5BOTI4MjU1ODg0NV5BMl5BanBnXkFtZTcwOTc0MTEzMQ@@._V1_SY1000_SX677_AL_.jpg',
#     title: 'Thousand Pieces of Gold',
#     fullplot: "In 1880's China, young Lalu is sold into marriage by her impoverished father. Rather than becoming a bride, Lalu ends up in an Idaho gold-mining town, the property of a saloon owner who renames her China Polly and plans to sell her as entertainment for the locals. Refusing to become a whore, Lalu ultimately finds her own way in this strange country filled with white demons.",
#     languages: [ 'English' ],
#     released: ISODate('1991-11-01T00:00:00.000Z'),
#     directors: [ 'Nancy Kelly' ],
#     writers: [ 'Ruthanne Lum McCunn (novel)', 'Anne Makepeace (screenplay)' ],
#     awards: { wins: 1, nominations: 1, text: '1 win & 1 nomination.' },
#     lastupdated: '2015-08-15 00:56:02.600000000',
#     year: 1991,
#     imdb: { rating: 7.2, votes: 390, id: 100774 },
#     countries: [ 'USA', 'UK' ],
#     type: 'movie',
#     tomatoes: {
#       viewer: { rating: 3.7, numReviews: 302, meter: 71 },
#       dvd: ISODate('1998-01-01T00:00:00.000Z'),
#       production: 'Hemdale Home Video',
#       lastUpdated: ISODate('2015-09-12T17:09:42.000Z')
#     }
#   },
#   {
#     _id: ObjectId('573a1399f29313caabcec3d1'),
#     plot: 'The "Brigatte Veneno" is a fan group from the soccer club "AS Roma". The next match is against "Juventus Turin", the classic prestige duel. Principe, the former leader of the group, has ...',
#     genres: [ 'Drama', 'Sport' ],
#     runtime: 95,
#     cast: [
#       'Claudio Amendola',
#       'Ricky Memphis',
#       'Gianmarco Tognazzi',
#       'Giuppy Izzo'
#     ],
#     poster: 'https://m.media-amazon.com/images/M/MV5BNzg5OTg1NzY3OF5BMl5BanBnXkFtZTgwNDQxNjkwMzE@._V1_SY1000_SX677_AL_.jpg',
#     title: 'Ultrè',
#     fullplot: 'The "Brigatte Veneno" is a fan group from the soccer club "AS Roma". The next match is against "Juventus Turin", the classic prestige duel. Principe, the former leader of the group, has been dismissed from jail a few days before. He has to realize that his best friend Red has not only taken over control of the group, but also has started an affair with his girlfriend. The rivalry between the hot-blooded Principe and the sensible Red causes an anxious mood within the group. When Smilzo, a member of the group, dies during a street fight with another fan group, Red knows that Principe is to be blamed for this catastrophe.',
#     languages: [ 'Italian' ],
#     released: ISODate('1991-03-01T00:00:00.000Z'),
#     directors: [ 'Ricky Tognazzi' ],
#     writers: [
#       'Simona Izzo (story)',
#       'Graziano Diana (story)',
#       'Ricky Tognazzi (story)',
#       'Graziano Diana (screenplay)',
#       'Simona Izzo (screenplay)',
#       'Giuseppe Manfridi (screenplay)'
#     ],
#     awards: { wins: 6, nominations: 15, text: '6 wins & 15 nominations.' },
#     lastupdated: '2015-07-08 02:13:55.153000000',
#     year: 1991,
#     imdb: { rating: 6.6, votes: 559, id: 100835 },
#     countries: [ 'Italy' ],
#     type: 'movie',
#     tomatoes: {
#       viewer: { rating: 2.9, numReviews: 20 },
#       lastUpdated: ISODate('2015-07-02T19:35:14.000Z')
#     },
#     num_mflix_comments: 0
#   },
#   {
#     _id: ObjectId('573a1399f29313caabcec488'),
#     plot: 'A romantic and action packed story of three best friends, a group of high end art thieves, who come into trouble when a love-triangle forms between them.',
#     genres: [ 'Action', 'Comedy', 'Crime' ],
#     runtime: 103,
#     rated: 'R',
#     cast: [ 'Yun-Fat Chow', 'Leslie Cheung', 'Cherie Chung', 'Kong Chu' ],
#     poster: 'https://m.media-amazon.com/images/M/MV5BZDY5Mjk5YTgtZmVjYS00NTBjLTlkZjgtMTg0OGQxZjc4YTZiXkEyXkFqcGdeQXVyMjUyNDk2ODc@._V1_SY1000_SX677_AL_.jpg',
#     title: 'Once a Thief',
#     fullplot: 'Once a Thief is an action/comedy/romance movie involving the plight of three master thieves (in the mode of Pink Panther). All three were raised by the same father and in fact were most certainly street orphans. The story begins with a successful art heist followed by a pledge to make this the last crime ever for the trio. The plot revolves around the theft of a mysterious "cursed" painting and how its obsession affects the family.',
#     languages: [ 'French', 'Cantonese', 'English', 'Hakka' ],
#     released: ISODate('1991-02-02T00:00:00.000Z'),
#     directors: [ 'John Woo' ],
#     writers: [
#       'Janet Chun',
#       'Clifton Ko',
#       'John Woo (screenplay)',
#       'John Woo (story)'
#     ],
#     awards: { wins: 0, nominations: 4, text: '4 nominations.' },
#     lastupdated: '2015-08-08 00:20:09.413000000',
#     year: 1991,
#     imdb: { rating: 6.8, votes: 4271, id: 101020 },
#     countries: [ 'Hong Kong' ],
#     type: 'movie',
#     tomatoes: {
#       viewer: { rating: 3.4, numReviews: 652, meter: 55 },
#       dvd: ISODate('2003-04-22T00:00:00.000Z'),
#       critic: { rating: 6.5, numReviews: 5, meter: 60 },
#       lastUpdated: ISODate('2015-09-15T18:26:42.000Z'),
#       rotten: 2,
#       production: 'Rim Film Distributors',
#       fresh: 3
#     },
#     num_mflix_comments: 0
#   },
#   {
#     _id: ObjectId('573a1399f29313caabcec4ba'),
#     plot: 'The true story of Helen Betty Osborne, a 19 year old Indian girl who was brutually murdered and slain on November 12, 1971 in The Pas, Manitoba, Canada and nearly taking 20 years for the ...',
#     genres: [ 'Crime', 'Drama', 'Mystery' ],
#     runtime: 240,
#     cast: [
#       'Michael Mahonen',
#       'Ian Tracey',
#       'Jonathan Potts',
#       'Diego Chambers'
#     ],
#     num_mflix_comments: 1,
#     poster: 'https://m.media-amazon.com/images/M/MV5BMTg5ODIxOTk5NV5BMl5BanBnXkFtZTcwMDI2MjgxMQ@@._V1_SY1000_SX677_AL_.jpg',
#     title: 'Conspiracy of Silence',
#     fullplot: 'The true story of Helen Betty Osborne, a 19 year old Indian girl who was brutually murdered and slain on November 12, 1971 in The Pas, Manitoba, Canada and nearly taking 20 years for the police to find the four men who murdered her.',
#     languages: [ 'English' ],
#     released: ISODate('1992-07-26T00:00:00.000Z'),
#     awards: { wins: 7, nominations: 1, text: '7 wins & 1 nomination.' },
#     lastupdated: '2015-09-02 00:48:23.383000000',
#     year: 1991,
#     imdb: { rating: 8, votes: 169, id: 101070 },
#     countries: [ 'Canada' ],
#     type: 'series',
#     tomatoes: {
#       viewer: { rating: 2.5, numReviews: 47 },
#       dvd: ISODate('2002-08-26T00:00:00.000Z'),
#       lastUpdated: ISODate('2015-01-02T04:28:41.000Z')
#     }
#   },
#   {
#     _id: ObjectId('573a1399f29313caabcec4d2'),
#     plot: "During archery in a wood Princess Fantaghiro is discovered by the hostile king's son Romualdo. He is able to take a short look at her before she can escape and immediately falls in love ...",
#     genres: [ 'Fantasy', 'Romance' ],
#     runtime: 200,
#     cast: [
#       'Alessandra Martines',
#       'Mario Adorf',
#       'Kim Rossi Stuart',
#       'èngela Molina'
#     ],
#     poster: 'https://m.media-amazon.com/images/M/MV5BMTAzMDE1NDkyNzReQTJeQWpwZ15BbWU3MDU4NjI2MTE@._V1_SY1000_SX677_AL_.jpg',
#     title: 'The Cave of the Golden Rose',
#     fullplot: "During archery in a wood Princess Fantaghiro is discovered by the hostile king's son Romualdo. He is able to take a short look at her before she can escape and immediately falls in love with the unknown beauty. When Romulado challenges her father for a duel to end the bloody war between their people Fantaghiro is send out to fight him due to a prophecy. As Romualdo sees her dressed as a man he believes to recognize his beloved. So he tries everything to discover wether she is a man or a woman and prevent the duel. Fantaghiro starts to fall in love with him, too, but her sense of duty is strong. Will love bring them together or will it end as a tragedy?",
#     languages: [ 'Italian' ],
#     released: ISODate('1991-12-22T00:00:00.000Z'),
#     directors: [ 'Lamberto Bava' ],
#     writers: [
#       'Francesca Melandri (story)',
#       'Gianni Romoli (story)',
#       'Italo Calvino (short story "Fanta-Ghirè',
#       ' persona bella")'
#     ],
#     awards: { wins: 1, nominations: 0, text: '1 win.' },
#     lastupdated: '2015-08-22 01:04:42.233000000',
#     year: 1991,
#     imdb: { rating: 7.6, votes: 1681, id: 101095 },
#     countries: [ 'Italy' ],
#     type: 'movie',
#     num_mflix_comments: 0
#   },
#   {
#     _id: ObjectId('573a1399f29313caabcec570'),
#     plot: 'Director Michael Apted revisits the same group of British-born adults after a 7 year wait. The subjects are interviewed as to the changes that have occurred in their lives during the last ...',
#     genres: [ 'Documentary', 'Biography' ],
#     runtime: 123,
#     cast: [
#       'Bruce Balden',
#       'Jacqueline Bassett',
#       'Symon Basterfield',
#       'Andrew Brackfield'
#     ],
#     poster: 'https://m.media-amazon.com/images/M/MV5BOTUzNzYzNTU0OF5BMl5BanBnXkFtZTcwNTE2NDkyMQ@@._V1_SY1000_SX677_AL_.jpg',
#     title: '35 Up',
#     fullplot: 'Director Michael Apted revisits the same group of British-born adults after a 7 year wait. The subjects are interviewed as to the changes that have occurred in their lives during the last seven years.',
#     languages: [ 'English', 'Bengali', 'Bulgarian' ],
#     released: ISODate('1992-01-15T00:00:00.000Z'),
#     directors: [ 'Michael Apted' ],
#     awards: { wins: 1, nominations: 1, text: '1 win & 1 nomination.' },
#     lastupdated: '2015-09-07 00:18:17.537000000',
#     year: 1991,
#     imdb: { rating: 8.2, votes: 1645, id: 101254 },
#     countries: [ 'UK' ],
#     type: 'movie',
#     tomatoes: {
#       viewer: { rating: 4.1, numReviews: 1136, meter: 91 },
#       dvd: ISODate('2004-10-19T00:00:00.000Z'),
#       critic: { rating: 7.9, numReviews: 17, meter: 94 },
#       lastUpdated: ISODate('2015-09-10T17:37:07.000Z'),
#       rotten: 1,
#       production: 'Granada Television Productions',
#       fresh: 16
#     },
#     num_mflix_comments: 0
#   },
#   {
#     _id: ObjectId('573a1399f29313caabcec582'),
#     plot: 'Con artists plan to fleece the eccentric family using an accomplice who claims to be their long lost Uncle Fester.',
#     genres: [ 'Comedy', 'Fantasy' ],
#     runtime: 99,
#     rated: 'PG-13',
#     cast: [
#       'Anjelica Huston',
#       'Raul Julia',
#       'Christopher Lloyd',
#       'Dan Hedaya'
#     ],
#     num_mflix_comments: 0,
#     poster: 'https://m.media-amazon.com/images/M/MV5BODc1NmY0MDUtNjUzNS00ODdhLWJlN2ItMTgwZjczZjI0MDkyXkEyXkFqcGdeQXVyNTAyODkwOQ@@._V1_SY1000_SX677_AL_.jpg',
#     title: 'The Addams Family',
#     fullplot: "The Addams step out of Charles Addams' cartoons. They live with all of the trappings of the macabre (including a detached hand for a servant) and are quite wealthy. Added to this mix is a crooked accountant and his loan shark and a plot to slip in the shark's son into the family as their long lost Uncle Fester. Can the false Fester find his way into the vault before he is discovered?",
#     languages: [ 'English' ],
#     released: ISODate('1991-11-22T00:00:00.000Z'),
#     directors: [ 'Barry Sonnenfeld' ],
#     writers: [
#       'Charles Addams (characters)',
#       'Caroline Thompson',
#       'Larry Wilson'
#     ],
#     awards: {
#       wins: 5,
#       nominations: 15,
#       text: 'Nominated for 1 Oscar. Another 4 wins & 15 nominations.'
#     },
#     lastupdated: '2015-09-04 00:41:12.833000000',
#     year: 1991,
#     imdb: { rating: 6.8, votes: 87966, id: 101272 },
#     countries: [ 'USA' ],
#     type: 'movie',
#     tomatoes: {
#       viewer: { rating: 3.2, numReviews: 314083, meter: 66 },
#       dvd: ISODate('2000-02-22T00:00:00.000Z'),
#       critic: { rating: 5.6, numReviews: 40, meter: 60 },
#       lastUpdated: ISODate('2015-09-14T18:28:14.000Z'),
#       consensus: "The movie is peppered with amusing sight gags and one-liners, but the disjointed script doesn't cohere into a successful whole.",
#       rotten: 16,
#       production: 'Paramount Pictures',
#       fresh: 24
#     }
#   },
#   {
#     _id: ObjectId('573a1399f29313caabcec58c'),
#     plot: "A reflection about what makes everyone's life unique, through the story of Noah's family. Noah is an adjuster, having sex with his customers. His wife Hera watches pornographic movies for ...",
#     genres: [ 'Comedy', 'Drama' ],
#     runtime: 102,
#     rated: 'R',
#     cast: [
#       'Elias Koteas',
#       'Arsinèe Khanjian',
#       'Maury Chaykin',
#       'Gabrielle Rose'
#     ],
#     num_mflix_comments: 0,
#     poster: 'https://m.media-amazon.com/images/M/MV5BZjY4ZTdjZTItZmM1Ny00ZjIyLWI4OGYtOWY5NjY5YjA3ZDNiXkEyXkFqcGdeQXVyNzc5MjA3OA@@._V1_SY1000_SX677_AL_.jpg',
#     title: 'The Adjuster',
#     fullplot: "A reflection about what makes everyone's life unique, through the story of Noah's family. Noah is an adjuster, having sex with his customers. His wife Hera watches pornographic movies for the Board of Censors. They live with their son Simon and Hera's sister in a show-flat. One day, they meet Bubba, who wants to make a movie in their house.",
#     languages: [ 'English' ],
#     released: ISODate('1992-07-01T00:00:00.000Z'),
#     directors: [ 'Atom Egoyan' ],
#     writers: [ 'Atom Egoyan' ],
#     awards: { wins: 5, nominations: 2, text: '5 wins & 2 nominations.' },
#     lastupdated: '2015-08-16 00:38:44.963000000',
#     year: 1991,
#     imdb: { rating: 6.8, votes: 2464, id: 101273 },
#     countries: [ 'Canada' ],
#     type: 'movie',
#     tomatoes: {
#       viewer: { rating: 3.6, numReviews: 1298, meter: 74 },
#       dvd: ISODate('2001-04-10T00:00:00.000Z'),
#       critic: { rating: 6.7, numReviews: 11, meter: 73 },
#       lastUpdated: ISODate('2015-09-11T17:41:30.000Z'),
#       rotten: 3,
#       production: 'Alliance Atlantis Communications',
#       fresh: 8
#     }
#   },
#   {
#     _id: ObjectId('573a1399f29313caabcec598'),
#     plot: "A well-off family is paid an unexpected, and rather unwanted, visit by a man claiming to be the woman's long-lost uncle. The initial suspicion with which they greet the man slowly dissolves...",
#     genres: [ 'Drama' ],
#     runtime: 97,
#     cast: [
#       'Dipankar Dey',
#       'Mamata Shankar',
#       'Bikram Bhattacharya',
#       'Utpal Dutt'
#     ],
#     num_mflix_comments: 2,
#     poster: 'https://m.media-amazon.com/images/M/MV5BYzliMzVhZWMtZTFkNy00YmNlLWJkMGYtZWEyZmM2ZTVhMWQwXkEyXkFqcGdeQXVyMTQxNzMzNDI@._V1_SY1000_SX677_AL_.jpg',
#     title: 'The Stranger',
#     fullplot: "A well-off family is paid an unexpected, and rather unwanted, visit by a man claiming to be the woman's long-lost uncle. The initial suspicion with which they greet the man slowly dissolves as he regales them with stories of his travels, tales that are at odds with their conventional middle-class perspective on the world.",
#     languages: [ 'Bengali', 'English' ],
#     released: ISODate('1992-08-26T00:00:00.000Z'),
#     directors: [ 'Satyajit Ray' ],
#     writers: [
#       'Satyajit Ray (scenario)',
#       'Satyajit Ray (screenplay)',
#       'Satyajit Ray (story)'
#     ],
#     awards: { wins: 2, nominations: 0, text: '2 wins.' },
#     lastupdated: '2015-06-24 00:12:57.643000000',
#     year: 1991,
#     imdb: { rating: 8, votes: 1282, id: 101279 },
#     countries: [ 'France', 'India' ],
#     type: 'movie',
#     tomatoes: {
#       viewer: { rating: 4.3, numReviews: 487, meter: 98 },
#       dvd: ISODate('2010-02-15T00:00:00.000Z'),
#       critic: { rating: 8.2, numReviews: 9, meter: 100 },
#       lastUpdated: ISODate('2015-08-03T19:05:32.000Z'),
#       rotten: 0,
#       fresh: 9
#     }
#   },
#   {
#     _id: ObjectId('573a1399f29313caabcec59c'),
#     plot: 'Hallie and Ethans divorced mother is about to remarry. When Hallie goes to visit Santa Claus, she asks for an unusual gift - she wants her parents back together again.',
#     genres: [ 'Comedy', 'Family', 'Romance' ],
#     runtime: 92,
#     rated: 'G',
#     cast: [
#       'Harley Jane Kozak',
#       'Jamey Sheridan',
#       'Ethan Embry',
#       'Kevin Nealon'
#     ],
#     num_mflix_comments: 1,
#     poster: 'https://m.media-amazon.com/images/M/MV5BY2QwOTE0YTUtNTBkNy00NTExLTgwMzItYjkxOWViM2RmMzdlXkEyXkFqcGdeQXVyNzc5MjA3OA@@._V1_SY1000_SX677_AL_.jpg',
#     title: 'All I Want for Christmas',
#     fullplot: `"All I Want For Christmas" is a comedy about two New York City children who launch a hilarious scheme to get what they most want this holiday season. Ethan, a practical older brother, and adorable Hallie, who knows how to charm her way out of a difficult situation, are intent on spending Christmas with their parents, Catherine and Micheal, and grandmother Lillian. As Ethan and Hallie embark on their adventure, almost nothing goes exactly as they planned. Complicating things is a smarmy businessman named Toney Boer, who has taken an interest in Catherine. Ethan, meanwhile, is preoccupied with not only his parents' romantic dilemma, but also his own - one brought about by his new friendship with Stephanie, his first teenage crush. What evolves is an elaborate scheme involving mice, telephone calls and an ice-cream truck, as Ethan and Hallie try to achieve their goal with the help of Stephanie. The duo's primary obstacle is their mother's fiance, Tony. The children finally succeed with a little Christmas magic from Santa Claus.`,
#     languages: [ 'English' ],
#     released: ISODate('1991-11-08T00:00:00.000Z'),
#     directors: [ 'Robert Lieberman' ],
#     writers: [ 'Thom Eberhardt', 'Richard Kramer' ],
#     awards: { wins: 0, nominations: 3, text: '3 nominations.' },
#     lastupdated: '2015-09-14 10:28:24.260000000',
#     year: 1991,
#     imdb: { rating: 6, votes: 2875, id: 101301 },
#     countries: [ 'USA' ],
#     type: 'movie',
#     tomatoes: {
#       viewer: { rating: 3.1, numReviews: 9689, meter: 60 },
#       dvd: ISODate('2004-10-05T00:00:00.000Z'),
#       critic: { rating: 3, numReviews: 13, meter: 0 },
#       lastUpdated: ISODate('2015-08-24T18:52:14.000Z'),
#       rotten: 13,
#       production: 'Paramount Home Video',
#       fresh: 0
#     }
#   },
#   {
#     _id: ObjectId('573a1399f29313caabcec5ac'),
#     plot: "Alex, who's homeless and addicted to alcohol, and Michèle, who's losing her sight, form a relationship while sleeping rough on Paris's Pont-Neuf bridge.",
#     genres: [ 'Drama', 'Romance' ],
#     runtime: 125,
#     rated: 'R',
#     cast: [
#       'Juliette Binoche',
#       'Denis Lavant',
#       'Daniel Buain',
#       'Klaus-Michael Grèber'
#     ],
#     num_mflix_comments: 1,
#     poster: 'https://m.media-amazon.com/images/M/MV5BZmRlMzg3NjAtNzQzYi00ZTRlLTk0YzctNjVhMjM5MjA0NWRlXkEyXkFqcGdeQXVyMjIyNzU0OA@@._V1_SY1000_SX677_AL_.jpg',
#     title: 'The Lovers on the Bridge',
#     fullplot: "Set against Paris' oldest bridge, the Pont Neuf, while it was closed for repairs, this film is a love story between two young vagrants: Alex, a would be circus performer addicted to alcohol and sedatives and Michele, a painter driven to a life on the streets because of a failed relationship and an affliction which is slowly turning her blind. The film portrays the harsh existence of the homeless as Alex, Michele and Hans, an older vagrant survive on the streets with their wits. As they both slowly get their lives back together, Michele becomes increasingly dependent on Alex as her vision deteriorates further. Fearing that Michele will leave him if she receives a new medical treatment Alex attempts to keep Michele practically a prisoner. The streets, skies and waterways of Paris are used as a backdrop to the story in a series of stunning visuals which dominate the film.",
#     languages: [ 'French' ],
#     released: ISODate('1999-07-02T00:00:00.000Z'),
#     directors: [ 'Leos Carax' ],
#     writers: [ 'Leos Carax' ],
#     awards: {
#       wins: 5,
#       nominations: 5,
#       text: 'Nominated for 1 BAFTA Film Award. Another 4 wins & 5 nominations.'
#     },
#     lastupdated: '2015-09-14 08:37:47.610000000',
#     year: 1991,
#     imdb: { rating: 7.5, votes: 8070, id: 101318 },
#     countries: [ 'France' ],
#     type: 'movie',
#     tomatoes: {
#       viewer: { rating: 4, numReviews: 5523, meter: 89 },
#       dvd: ISODate('2004-01-13T00:00:00.000Z'),
#       critic: { rating: 7.2, numReviews: 18, meter: 83 },
#       lastUpdated: ISODate('2015-08-24T19:18:23.000Z'),
#       rotten: 3,
#       production: 'Miramax Films',
#       fresh: 15
#     }
#   },
#   {
#     _id: ObjectId('573a1399f29313caabcec5bb'),
#     plot: 'Francis Ashby, a senior Oxford don on holiday alone in the Alps, meets holidaying American Caroline and her companion Elinor, the blossoming Irish-American girl she adopted many years ...',
#     genres: [ 'Comedy', 'Drama' ],
#     runtime: 95,
#     rated: 'PG',
#     cast: [
#       'Bryan Pringle',
#       'Fred Pearson',
#       'Michael Palin',
#       'Alfred Molina'
#     ],
#     poster: 'https://m.media-amazon.com/images/M/MV5BMDVmNjMyZWQtMTc0Zi00MjA2LWFjZjEtZDMwYjIyMjhhYmJiXkEyXkFqcGdeQXVyMjE4MTIyNDI@._V1_SY1000_SX677_AL_.jpg',
#     title: 'American Friends',
#     fullplot: 'Francis Ashby, a senior Oxford don on holiday alone in the Alps, meets holidaying American Caroline and her companion Elinor, the blossoming Irish-American girl she adopted many years before. Ashby finds he enjoys their company, particularly that of Elinor, and both the women are drawn to him. Back at Oxford he is nevertheless taken aback when they arrive unannounced. Women are not allowed in the College grounds, let alone the rooms. Indeed any liaison, however innocent, is frowned on by the upstanding Fellows.',
#     languages: [ 'English' ],
#     released: ISODate('1993-04-01T00:00:00.000Z'),
#     directors: [ 'Tristram Powell' ],
#     writers: [
#       'Michael Palin (story)',
#       'Michael Palin (screenplay)',
#       'Tristram Powell (screenplay)'
#     ],
#     awards: { wins: 1, nominations: 1, text: '1 win & 1 nomination.' },
#     lastupdated: '2015-09-07 01:15:50.887000000',
#     year: 1991,
#     imdb: { rating: 6.6, votes: 526, id: 101324 },
#     countries: [ 'UK' ],
#     type: 'movie',
#     tomatoes: {
#       viewer: { rating: 3.3, numReviews: 405, meter: 45 },
#       dvd: ISODate('2000-01-01T00:00:00.000Z'),
#       production: 'Castle Hill',
#       lastUpdated: ISODate('2015-08-18T19:30:22.000Z')
#     },
#     num_mflix_comments: 0
#   },
#   {
#     _id: ObjectId('573a1399f29313caabcec5c4'),
#     plot: 'Two inventor brothers create a working robot that is also inhabited by the spirit of their dead father.',
#     genres: [ 'Comedy', 'Family', 'Fantasy' ],
#     runtime: 92,
#     rated: 'PG',
#     cast: [
#       'Marcia Strassman',
#       'Joshua John Miller',
#       'Edan Gross',
#       'John Quade'
#     ],
#     num_mflix_comments: 0,
#     poster: 'https://m.media-amazon.com/images/M/MV5BYTc4MmZiYWYtM2I2ZS00OGM4LWI1ODgtMTM1OGQ3MDVjZDUzXkEyXkFqcGdeQXVyMTQxNzMzNDI@._V1_SY1000_SX677_AL_.jpg',
#     title: 'And You Thought Your Parents Were Weird',
#     fullplot: "Two boys follow in their late father's footsteps by inventing weird and wonderful gadgets. Trouble lies ahead when, after a Halloween party, the spirit of their father ends up in the latest invention, a robot.",
#     languages: [ 'English' ],
#     released: ISODate('1991-11-15T00:00:00.000Z'),
#     directors: [ 'Tony Cookson' ],
#     writers: [ 'Tony Cookson' ],
#     awards: { wins: 0, nominations: 4, text: '4 nominations.' },
#     lastupdated: '2015-09-13 00:00:46.957000000',
#     year: 1991,
#     imdb: { rating: 4.4, votes: 361, id: 101343 },
#     countries: [ 'USA' ],
#     type: 'movie',
#     tomatoes: {
#       viewer: { rating: 3.2, numReviews: 270, meter: 33 },
#       dvd: ISODate('1992-02-19T00:00:00.000Z'),
#       production: 'Trimark',
#       lastUpdated: ISODate('2015-09-11T18:52:51.000Z')
#     }
#   }
# ]
# Type "it" for more

# %%
aggString = "db.movies.aggregate([{\$match:{year:1991}},{\$skip:3}])"

print(aggString.replace("\\", ""))
print("")

# !mongosh {mongoDB_connection_string} --quiet  --username {mongoDB_username} -p {mongoDB_password} \
--eval "use sample_mflix" \
--eval """{aggString}"""
# Out:
# db.movies.aggregate([{$match:{year:1991}},{$skip:3}])
#
#  [
#   {
#     _id: ObjectId("573a1398f29313caabcebdf2"),
#     plot: 'Over more than thirty years, a department of the Condesa in Mexico City, is the setting in which they are carried out ten stories, mixed, form one whose only constant is the rupture. The ...',
#     genres: [ 'Drama' ],
#     runtime: 87,
#     cast: [
#       'Gabriela Roel',
#       'Arcelia Ramèrez',
#       'Verènica Merchant',
#       'Roberto Sosa'
#     ],
#     num_mflix_comments: 0,
#     title: 'City of the Blind',
#     fullplot: 'Over more than thirty years, a department of the Condesa in Mexico City, is the setting in which they are carried out ten stories, mixed, form one whose only constant is the rupture. The passage of time and the outside world only guess through the windows and objects that come with the characters. The set is a great solitude, possible in a city of the blind.',
#     languages: [ 'Spanish' ],
#     released: ISODate("1991-10-31T00:00:00.000Z"),
#     directors: [ 'Alberto Cortès' ],
#     writers: [
#       'Josè Agustèn',
#       'Hernann Bellinghaussen',
#       'Alberto Cortès',
#       'Marcela Fuentes-Berain',
#       'Paz Alicia Garciadiego',
#       'Silvia Tomasa Rivera'
#     ],
#     awards: { wins: 3, nominations: 2, text: '3 wins & 2 nominations.' },
#     lastupdated: '2015-06-04 00:55:24.303000000',
#     year: 1991,
#     imdb: { rating: 6.6, votes: 75, id: 99274 },
#     countries: [ 'Mexico' ],
#     type: 'movie',
#     tomatoes: {
#       viewer: { rating: 3, numReviews: 27, meter: 50 },
#       dvd: ISODate("2008-05-20T00:00:00.000Z"),
#       lastUpdated: ISODate("2015-07-02T19:14:26.000Z")
#     }
#   },
#   {
#     _id: ObjectId("573a1398f29313caabcebf0b"),
#     plot: 'Agent Jackie is hired to find WWII Nazi gold hidden in the Sahara desert. He teams up with three bundling women (the 3 stooges?) who are all connected in some way. However a team of ...',
#     genres: [ 'Action', 'Adventure', 'Comedy' ],
#     runtime: 80,
#     rated: 'PG-13',
#     cast: [ 'Jackie Chan', "Carol 'Do Do' Cheng", 'Eva Cobo', 'Shèko Ikeda' ],
#     poster: 'https://m.media-amazon.com/images/M/MV5BNjEyMTk4ZDgtNjUyZi00OTg0LWFkMWEtNjk0ZWE5N2QwMmZmXkEyXkFqcGdeQXVyNjU5MjcxOTg@._V1_SY1000_SX677_AL_.jpg',
#     title: 'Armour of God 2: Operation Condor',
#     fullplot: 'Agent Jackie is hired to find WWII Nazi gold hidden in the Sahara desert. He teams up with three bundling women (the 3 stooges?) who are all connected in some way. However a team of mercenries have ideas on the ownership of the gold. A battle / chase ensues as to who gets there first. Lots of choregraphed Kung-Fu and quirky Chan humour.',
#     languages: [ 'Cantonese' ],
#     released: ISODate("1997-07-18T00:00:00.000Z"),
#     directors: [ 'Jackie Chan' ],
#     writers: [ 'Jackie Chan', 'Edward Tang' ],
#     awards: { wins: 0, nominations: 1, text: '1 nomination.' },
#     lastupdated: '2015-09-02 00:24:33.507000000',
#     year: 1991,
#     imdb: { rating: 7.2, votes: 12598, id: 99558 },
#     countries: [ 'Hong Kong' ],
#     type: 'movie',
#     tomatoes: {
#       viewer: { rating: 3.2, numReviews: 17448, meter: 66 },
#       dvd: ISODate("1999-09-14T00:00:00.000Z"),
#       critic: { rating: 6.4, numReviews: 33, meter: 70 },
#       lastUpdated: ISODate("2015-08-25T18:56:21.000Z"),
#       rotten: 10,
#       production: 'Miramax',
#       fresh: 23
#     },
#     num_mflix_comments: 0
#   },
#   {
#     _id: ObjectId("573a1399f29313caabcec59c"),
#     plot: 'Hallie and Ethans divorced mother is about to remarry. When Hallie goes to visit Santa Claus, she asks for an unusual gift - she wants her parents back together again.',
#     genres: [ 'Comedy', 'Family', 'Romance' ],
#     runtime: 92,
#     rated: 'G',
#     cast: [
#       'Harley Jane Kozak',
#       'Jamey Sheridan',
#       'Ethan Embry',
#       'Kevin Nealon'
#     ],
#     num_mflix_comments: 1,
#     poster: 'https://m.media-amazon.com/images/M/MV5BY2QwOTE0YTUtNTBkNy00NTExLTgwMzItYjkxOWViM2RmMzdlXkEyXkFqcGdeQXVyNzc5MjA3OA@@._V1_SY1000_SX677_AL_.jpg',
#     title: 'All I Want for Christmas',
#     fullplot: `"All I Want For Christmas" is a comedy about two New York City children who launch a hilarious scheme to get what they most want this holiday season. Ethan, a practical older brother, and adorable Hallie, who knows how to charm her way out of a difficult situation, are intent on spending Christmas with their parents, Catherine and Micheal, and grandmother Lillian. As Ethan and Hallie embark on their adventure, almost nothing goes exactly as they planned. Complicating things is a smarmy businessman named Toney Boer, who has taken an interest in Catherine. Ethan, meanwhile, is preoccupied with not only his parents' romantic dilemma, but also his own - one brought about by his new friendship with Stephanie, his first teenage crush. What evolves is an elaborate scheme involving mice, telephone calls and an ice-cream truck, as Ethan and Hallie try to achieve their goal with the help of Stephanie. The duo's primary obstacle is their mother's fiance, Tony. The children finally succeed with a little Christmas magic from Santa Claus.`,
#     languages: [ 'English' ],
#     released: ISODate("1991-11-08T00:00:00.000Z"),
#     directors: [ 'Robert Lieberman' ],
#     writers: [ 'Thom Eberhardt', 'Richard Kramer' ],
#     awards: { wins: 0, nominations: 3, text: '3 nominations.' },
#     lastupdated: '2015-09-14 10:28:24.260000000',
#     year: 1991,
#     imdb: { rating: 6, votes: 2875, id: 101301 },
#     countries: [ 'USA' ],
#     type: 'movie',
#     tomatoes: {
#       viewer: { rating: 3.1, numReviews: 9689, meter: 60 },
#       dvd: ISODate("2004-10-05T00:00:00.000Z"),
#       critic: { rating: 3, numReviews: 13, meter: 0 },
#       lastUpdated: ISODate("2015-08-24T18:52:14.000Z"),
#       rotten: 13,
#       production: 'Paramount Home Video',
#       fresh: 0
#     }
#   },
#   {
#     _id: ObjectId("573a1399f29313caabcec5ac"),
#     plot: "Alex, who's homeless and addicted to alcohol, and Michèle, who's losing her sight, form a relationship while sleeping rough on Paris's Pont-Neuf bridge.",
#     genres: [ 'Drama', 'Romance' ],
#     runtime: 125,
#     rated: 'R',
#     cast: [
#       'Juliette Binoche',
#       'Denis Lavant',
#       'Daniel Buain',
#       'Klaus-Michael Grèber'
#     ],
#     num_mflix_comments: 1,
#     poster: 'https://m.media-amazon.com/images/M/MV5BZmRlMzg3NjAtNzQzYi00ZTRlLTk0YzctNjVhMjM5MjA0NWRlXkEyXkFqcGdeQXVyMjIyNzU0OA@@._V1_SY1000_SX677_AL_.jpg',
#     title: 'The Lovers on the Bridge',
#     fullplot: "Set against Paris' oldest bridge, the Pont Neuf, while it was closed for repairs, this film is a love story between two young vagrants: Alex, a would be circus performer addicted to alcohol and sedatives and Michele, a painter driven to a life on the streets because of a failed relationship and an affliction which is slowly turning her blind. The film portrays the harsh existence of the homeless as Alex, Michele and Hans, an older vagrant survive on the streets with their wits. As they both slowly get their lives back together, Michele becomes increasingly dependent on Alex as her vision deteriorates further. Fearing that Michele will leave him if she receives a new medical treatment Alex attempts to keep Michele practically a prisoner. The streets, skies and waterways of Paris are used as a backdrop to the story in a series of stunning visuals which dominate the film.",
#     languages: [ 'French' ],
#     released: ISODate("1999-07-02T00:00:00.000Z"),
#     directors: [ 'Leos Carax' ],
#     writers: [ 'Leos Carax' ],
#     awards: {
#       wins: 5,
#       nominations: 5,
#       text: 'Nominated for 1 BAFTA Film Award. Another 4 wins & 5 nominations.'
#     },
#     lastupdated: '2015-09-14 08:37:47.610000000',
#     year: 1991,
#     imdb: { rating: 7.5, votes: 8070, id: 101318 },
#     countries: [ 'France' ],
#     type: 'movie',
#     tomatoes: {
#       viewer: { rating: 4, numReviews: 5523, meter: 89 },
#       dvd: ISODate("2004-01-13T00:00:00.000Z"),
#       critic: { rating: 7.2, numReviews: 18, meter: 83 },
#       lastUpdated: ISODate("2015-08-24T19:18:23.000Z"),
#       rotten: 3,
#       production: 'Miramax Films',
#       fresh: 15
#     }
#   },
#   {
#     _id: ObjectId("573a1399f29313caabcec633"),
#     plot: 'A tyrant from the future creates evil android doubles of Bill and Ted and sends them back to eliminate the originals.',
#     genres: [ 'Adventure', 'Comedy', 'Fantasy' ],
#     runtime: 93,
#     metacritic: 60,
#     rated: 'PG',
#     cast: [ 'Keanu Reeves', 'Alex Winter', 'William Sadler', 'Joss Ackland' ],
#     poster: 'https://m.media-amazon.com/images/M/MV5BMjAwNjQyODA2Ml5BMl5BanBnXkFtZTcwNDM4MzcyNA@@._V1._CR14,27,635,974_SX178_AL_.jpg',
#     title: "Bill & Ted's Bogus Journey",
#     fullplot: 'The world of our distant future is a veritable utopia, thanks to the lyrics of two simple-minded 20th Century rock and rollers, Bill S. Preston, Esq. and Ted "Theodore" Logan. However, a would-be conquerer threatens to throw history off-track by sending "most non-non-heinous" evil robot Bill and Teds back to kill their good counterparts. Finding themselves dead, the boys must outwit the Grim Reaper and traverse Heaven and Hell to return to the land of the living, rescue their "babes" and have a "most triumphant" concert at the all-important Battle of the Bands.',
#     languages: [ 'English', 'Italian', 'Russian' ],
#     released: ISODate("1991-07-19T00:00:00.000Z"),
#     directors: [ 'Peter Hewitt' ],
#     writers: [
#       'Chris Matheson (characters)',
#       'Ed Solomon (characters)',
#       'Chris Matheson',
#       'Ed Solomon'
#     ],
#     awards: { wins: 1, nominations: 1, text: '1 win & 1 nomination.' },
#     lastupdated: '2015-08-31 00:06:33.247000000',
#     year: 1991,
#     imdb: { rating: 6.2, votes: 46454, id: 101452 },
#     countries: [ 'USA' ],
#     type: 'movie',
#     tomatoes: {
#       website: "http://www.mgm.com/#/our-titles/183/Bill-&-Ted's-Bogus-Journey",
#       viewer: { rating: 3, numReviews: 229883, meter: 56 },
#       dvd: ISODate("2001-12-04T00:00:00.000Z"),
#       critic: { rating: 6, numReviews: 37, meter: 57 },
#       lastUpdated: ISODate("2015-08-18T19:26:31.000Z"),
#       rotten: 16,
#       production: 'Orion Pictures Corp.',
#       fresh: 21
#     },
#     num_mflix_comments: 0
#   },
#   {
#     _id: ObjectId("573a1399f29313caabcec661"),
#     plot: 'After losing his arm in a car accident, a criminal psychologist has it replaced with a limb that belonged to a serial killer.',
#     genres: [ 'Horror', 'Thriller' ],
#     runtime: 88,
#     rated: 'R',
#     cast: [ 'Jeff Fahey', 'Lindsay Duncan', 'Kim Delaney', 'Zakes Mokae' ],
#     num_mflix_comments: 0,
#     poster: 'https://m.media-amazon.com/images/M/MV5BNTBiY2FhNzgtODI5NC00MTEzLTg1MzEtNmZhNzAyYWFlMGZkXkEyXkFqcGdeQXVyMTQxNzMzNDI@._V1_SY1000_SX677_AL_.jpg',
#     title: 'Body Parts',
#     fullplot: 'When Bill Chrashank loses his arm in a car accident, the arm of an executed death row inmate is grafted on in its place. The only problem, as Bill soon discovers, is that the arm is possessed by a force he cannot control.',
#     languages: [ 'English' ],
#     released: ISODate("1991-08-02T00:00:00.000Z"),
#     directors: [ 'Eric Red' ],
#     writers: [
#       'Pierre Boileau (novel)',
#       'Thomas Narcejac (novel)',
#       'Patricia Herskovic (screen story)',
#       'Joyce Taylor (screen story)',
#       'Eric Red (screenplay)',
#       'Norman Snider (screenplay)'
#     ],
#     awards: { wins: 2, nominations: 4, text: '2 wins & 4 nominations.' },
#     lastupdated: '2015-09-13 00:43:55.953000000',
#     year: 1991,
#     imdb: { rating: 5.4, votes: 2810, id: 101492 },
#     countries: [ 'USA' ],
#     type: 'movie',
#     tomatoes: {
#       viewer: { rating: 2.6, numReviews: 6960, meter: 35 },
#       dvd: ISODate("2004-09-14T00:00:00.000Z"),
#       critic: { rating: 4.4, numReviews: 15, meter: 40 },
#       lastUpdated: ISODate("2015-08-20T18:10:33.000Z"),
#       rotten: 9,
#       production: 'Paramount Home Video',
#       fresh: 6
#     }
#   },
#   {
#     _id: ObjectId("573a1399f29313caabcec68d"),
#     plot: "Old Thorgeir must leave his home far off in the Icelandic 'countryside' and move into a home for senior citizens in Reykjavik. There he meets an old friend from his childhood, Stella. ...",
#     genres: [ 'Drama', 'Romance' ],
#     runtime: 82,
#     cast: [
#       'Gèsli Halldèrsson',
#       'Sigrèèur Hagalèn',
#       'Baldvin Halldèrsson',
#       'Bjèrn Karlsson'
#     ],
#     poster: 'https://m.media-amazon.com/images/M/MV5BMTY4OTA2NzMxN15BMl5BanBnXkFtZTcwNDgzNzcyMQ@@._V1_SY1000_SX677_AL_.jpg',
#     title: 'Children of Nature',
#     fullplot: "Old Thorgeir must leave his home far off in the Icelandic 'countryside' and move into a home for senior citizens in Reykjavik. There he meets an old friend from his childhood, Stella. Thorgeir soon becomes unhappy living there and together with Stella he steals a jeep. Together they leave the city for Stella's old home in northwestern Iceland. A drama who asks us: how important is it to have a long life if you have to leave everything that has a meaning for you?",
#     languages: [ 'Icelandic', 'English' ],
#     released: ISODate("1991-08-01T00:00:00.000Z"),
#     directors: [ 'Frièrik èèr Frièriksson' ],
#     writers: [ 'Frièrik èèr Frièriksson', 'Einar Guèmundsson' ],
#     awards: {
#       wins: 6,
#       nominations: 1,
#       text: 'Nominated for 1 Oscar. Another 5 wins & 1 nomination.'
#     },
#     lastupdated: '2015-08-23 00:42:28.110000000',
#     year: 1991,
#     imdb: { rating: 7.7, votes: 1093, id: 101526 },
#     countries: [ 'Germany', 'Iceland', 'Norway' ],
#     type: 'movie',
#     tomatoes: {
#       viewer: { rating: 3.8, numReviews: 99, meter: 75 },
#       production: 'Wellspring Media Inc.',
#       lastUpdated: ISODate("2015-08-11T18:56:28.000Z")
#     },
#     num_mflix_comments: 0
#   },
#   {
#     _id: ObjectId("573a1399f29313caabcec690"),
#     plot: "In a fantastical 40's where magic is used by everyone, a hard-boiled detective investigates the theft of a mystical tome.",
#     genres: [ 'Comedy', 'Fantasy', 'Horror' ],
#     runtime: 96,
#     rated: 'R',
#     cast: [ 'Fred Ward', 'David Warner', 'Julianne Moore', 'Clancy Brown' ],
#     num_mflix_comments: 0,
#     poster: 'https://m.media-amazon.com/images/M/MV5BMjA4NjY2OTg0N15BMl5BanBnXkFtZTcwNzE4NjAyMQ@@._V1_SY1000_SX677_AL_.jpg',
#     title: 'Cast a Deadly Spell',
#     fullplot: `In 1948 Los Angeles, everyone uses magic- everyone except hard-boiled private detective H. Phillip Lovecraft, who refuses for "personal reasons." Lovecraft is hired by a mysterious rich man to recover a stolen book, the Necronomicon. Investigating, he finds that the book holds the key to taking over the world by magical means, releasing the "Old Ones". (Contains several in-jokes to H.P. Lovecraft's horror fiction and also the hard-boiled detective genre.)`,
#     languages: [ 'English' ],
#     released: ISODate("1991-09-07T00:00:00.000Z"),
#     directors: [ 'Martin Campbell' ],
#     writers: [ 'Joseph Dougherty' ],
#     awards: {
#       wins: 0,
#       nominations: 4,
#       text: 'Won 1 Primetime Emmy. Another 3 nominations.'
#     },
#     lastupdated: '2015-09-16 11:38:27.620000000',
#     year: 1991,
#     imdb: { rating: 6.7, votes: 1467, id: 101550 },
#     countries: [ 'USA' ],
#     type: 'movie',
#     tomatoes: {
#       viewer: { rating: 3.4, numReviews: 839, meter: 59 },
#       dvd: ISODate("1991-12-04T00:00:00.000Z"),
#       production: 'HBO Video',
#       lastUpdated: ISODate("2015-09-16T20:34:56.000Z")
#     }
#   },
#   {
#     _id: ObjectId("573a1399f29313caabcec6ac"),
#     plot: 'A beautiful film which is basically about a man, a piano player, who meets and falls in love with a beautiful and voluptuous woman, who, by some strange procedure, leaves the man unable to ...',
#     genres: [ 'Drama', 'Romance' ],
#     runtime: 90,
#     cast: [
#       'Sergio Castellitto',
#       'Francesca Dellera',
#       'Philippe Lèotard',
#       'Farid Chopel'
#     ],
#     num_mflix_comments: 1,
#     title: 'The Flesh',
#     fullplot: "A beautiful film which is basically about a man, a piano player, who meets and falls in love with a beautiful and voluptuous woman, who, by some strange procedure, leaves the man unable to move but with a permanent priapism! After some time he becomes sick of it and she relieves his paralysis. Eventually she gets bored and decides to leave, but he can't take it because he loves her...",
#     languages: [ 'Italian' ],
#     released: ISODate("1991-08-21T00:00:00.000Z"),
#     directors: [ 'Marco Ferreri' ],
#     writers: [
#       'Liliane Betti',
#       'Massimo Bucchi',
#       'Paolo Costella',
#       'Marco Ferreri'
#     ],
#     awards: { wins: 0, nominations: 3, text: '3 nominations.' },
#     lastupdated: '2015-08-13 00:30:28.003000000',
#     year: 1991,
#     imdb: { rating: 5.5, votes: 454, id: 101548 },
#     countries: [ 'Italy' ],
#     type: 'movie',
#     tomatoes: {
#       viewer: { rating: 3.3, numReviews: 49, meter: 50 },
#       lastUpdated: ISODate("2015-07-13T18:50:56.000Z")
#     }
#   },
#   {
#     _id: ObjectId("573a1399f29313caabcec6fb"),
#     plot: 'A young woman becomes the fourth wife of a wealthy lord, and must learn to live with the strict rules and tensions within the household.',
#     genres: [ 'Drama' ],
#     runtime: 125,
#     rated: 'PG',
#     cast: [ 'Li Gong', 'Saifei He', 'Cuifen Cao', 'Jingwu Ma' ],
#     poster: 'https://m.media-amazon.com/images/M/MV5BYjNiMDAyOTUtNTg5Ny00NTE4LThlZmYtYmNlNjUwOTlmNWZhL2ltYWdlL2ltYWdlXkEyXkFqcGdeQXVyNjc1NTYyMjg@._V1_SY1000_SX677_AL_.jpg',
#     title: 'Raise the Red Lantern',
#     fullplot: "China in the 1920's. After her father's death, nineteen year old Songlian is forced to marry Chen Zuoqian, the lord of a powerful family. Fifty year old Chen has already three wives, each of them living in separate houses within the great castle. The competition between the wives is tough, as their master's attention carries power, status and privilege. Each night Chen must decide with which wife to spend the night and a red lantern is lit in front of the house of his choice. And each wife schemes and plots to make sure it's hers. However, things get out of hand...",
#     languages: [ 'Mandarin' ],
#     released: ISODate("1991-12-20T00:00:00.000Z"),
#     directors: [ 'Yimou Zhang' ],
#     writers: [ 'Su Tong (novel)', 'Ni Zhen' ],
#     awards: {
#       wins: 23,
#       nominations: 5,
#       text: 'Nominated for 1 Oscar. Another 22 wins & 5 nominations.'
#     },
#     lastupdated: '2015-08-11 00:01:32.920000000',
#     year: 1991,
#     imdb: { rating: 8.2, votes: 19181, id: 101640 },
#     countries: [ 'China', 'Hong Kong', 'Taiwan' ],
#     type: 'movie',
#     tomatoes: {
#       viewer: { rating: 4.1, numReviews: 21953, meter: 94 },
#       dvd: ISODate("2006-02-14T00:00:00.000Z"),
#       critic: { rating: 8.4, numReviews: 25, meter: 96 },
#       lastUpdated: ISODate("2015-09-11T18:39:58.000Z"),
#       rotten: 1,
#       production: 'China Film Co-Production Corporation',
#       fresh: 24
#     },
#     num_mflix_comments: 0
#   },
#   {
#     _id: ObjectId("573a1399f29313caabcec715"),
#     fullplot: 'Mike Church is a Los Angeles private detective who specializes in finding missing persons. He takes on the case of a mystery woman whom he calls Grace. She is suffering from amnesia and has no memories of her own. She keeps having nightmares involving the murder of a pianist, Margaret, by her husband Roman Strauss in the late 1940s. In an attempt to solve the mystery about these nightmares, Church seeks the help of Madson who is an antiques dealer with the gift of hypnosis. The hypnosis sessions will soon begin to reveal some surprises.',
#     imdb: { rating: 7, votes: 21125, id: 101669 },
#     year: 1991,
#     plot: 'An amnesiac and a private eye find they might have a past life connection.',
#     genres: [ 'Crime', 'Drama', 'Mystery' ],
#     rated: 'R',
#     metacritic: 66,
#     title: 'Dead Again',
#     lastupdated: '2015-09-11 00:11:34.013000000',
#     languages: [ 'English' ],
#     writers: [ 'Scott Frank' ],
#     type: 'movie',
#     tomatoes: {
#       viewer: { rating: 3.6, numReviews: 11695, meter: 78 },
#       dvd: ISODate("2000-06-27T00:00:00.000Z"),
#       critic: { rating: 7.3, numReviews: 44, meter: 82 },
#       lastUpdated: ISODate("2015-08-22T18:35:26.000Z"),
#       rotten: 8,
#       production: 'Paramount Home Video',
#       fresh: 36
#     },
#     poster: 'https://m.media-amazon.com/images/M/MV5BZmM1Zjc3YTEtNDM4OC00ODI5LTlmMmUtYmIyZWZhNGJiYzZjXkEyXkFqcGdeQXVyNjU0NTI0Nw@@._V1_SY1000_SX677_AL_.jpg',
#     num_mflix_comments: 1,
#     released: ISODate("1991-08-30T00:00:00.000Z"),
#     awards: {
#       wins: 2,
#       nominations: 4,
#       text: 'Nominated for 1 Golden Globe. Another 1 win & 4 nominations.'
#     },
#     countries: [ 'USA' ],
#     cast: [
#       'Kenneth Branagh',
#       'Andy Garcia',
#       'Derek Jacobi',
#       'Wayne Knight'
#     ],
#     directors: [ 'Kenneth Branagh' ],
#     runtime: 107
#   },
#   {
#     _id: ObjectId("573a1399f29313caabcec756"),
#     plot: "Jack McKee is a doctor with it all: he's successful, he's rich, and he has no problems.... until he is diagnosed with throat cancer. Now that he has seen medicine, hospitals, and doctors ...",
#     genres: [ 'Drama' ],
#     runtime: 122,
#     rated: 'PG-13',
#     cast: [
#       'William Hurt',
#       'Christine Lahti',
#       'Elizabeth Perkins',
#       'Mandy Patinkin'
#     ],
#     num_mflix_comments: 0,
#     poster: 'https://m.media-amazon.com/images/M/MV5BNzc5NTVlYmItYjI3NC00NzljLWE3MGYtNDgxZjYwYzYxNTIyXkEyXkFqcGdeQXVyNzc5MjA3OA@@._V1_SY1000_SX677_AL_.jpg',
#     title: 'The Doctor',
#     fullplot: "Jack McKee is a doctor with it all: he's successful, he's rich, and he has no problems.... until he is diagnosed with throat cancer. Now that he has seen medicine, hospitals, and doctors from a patient's perspective, he realises that there is more to being a doctor than surgery and prescriptions.",
#     languages: [ 'English' ],
#     released: ISODate("1991-08-16T00:00:00.000Z"),
#     directors: [ 'Randa Haines' ],
#     writers: [ 'Ed Rosenbaum (book)', 'Robert Caswell (screenplay)' ],
#     awards: { wins: 0, nominations: 3, text: '3 nominations.' },
#     lastupdated: '2015-08-20 00:26:31.360000000',
#     year: 1991,
#     imdb: { rating: 6.9, votes: 3873, id: 101746 },
#     countries: [ 'USA' ],
#     type: 'movie',
#     tomatoes: {
#       viewer: { rating: 3.4, numReviews: 3287, meter: 72 },
#       dvd: ISODate("2004-04-06T00:00:00.000Z"),
#       critic: { rating: 6.9, numReviews: 13, meter: 85 },
#       lastUpdated: ISODate("2015-09-14T18:07:21.000Z"),
#       rotten: 2,
#       fresh: 11
#     }
#   },
#   {
#     _id: ObjectId("573a1399f29313caabcec760"),
#     plot: 'Hitman Dekker is on his last job, out to kill the wife (Jain) of his client, but he starts to waver. The longer he takes to do the job, the more difficult it becomes.',
#     genres: [ 'Crime', 'Drama' ],
#     runtime: 90,
#     rated: 'R',
#     cast: [
#       'Forest Whitaker',
#       'Peter White',
#       'John Bedford Lloyd',
#       'Seymour Cassel'
#     ],
#     poster: 'https://m.media-amazon.com/images/M/MV5BYTFlNzdhYWQtNGZiOS00NTA5LWJmMzEtOGJjY2RkNDc5NjRmXkEyXkFqcGdeQXVyNTc1NTQxODI@._V1_SY1000_SX677_AL_.jpg',
#     title: 'Diary of a Hitman',
#     fullplot: 'Hitman Dekker is on his last job, out to kill the wife (Jain) of his client, but he starts to waver. The longer he takes to do the job, the more difficult it becomes.',
#     languages: [ 'English' ],
#     released: ISODate("1991-11-20T00:00:00.000Z"),
#     directors: [ 'Roy London' ],
#     writers: [ 'Kenneth Pressman (play)', 'Kenneth Pressman (screenplay)' ],
#     awards: { wins: 0, nominations: 1, text: '1 nomination.' },
#     lastupdated: '2015-08-31 00:17:53.590000000',
#     year: 1991,
#     imdb: { rating: 5.4, votes: 1246, id: 101725 },
#     countries: [ 'USA' ],
#     type: 'movie',
#     tomatoes: {
#       viewer: { rating: 2.9, numReviews: 478, meter: 39 },
#       dvd: ISODate("1992-05-27T00:00:00.000Z"),
#       lastUpdated: ISODate("2015-08-05T18:15:43.000Z")
#     },
#     num_mflix_comments: 0
#   },
#   {
#     _id: ObjectId("573a1399f29313caabcec769"),
#     plot: 'Jean Claude Van Damme plays a dual role as Alex and Chad, twins separated at the death of their parents. Chad is raised by a family retainer in Paris, Alex becomes a petty crook in Hong ...',
#     genres: [ 'Action', 'Comedy', 'Crime' ],
#     runtime: 110,
#     rated: 'R',
#     cast: [
#       'Jean-Claude Van Damme',
#       'Geoffrey Lewis',
#       'Alonna Shaw',
#       'Corinna Everson'
#     ],
#     num_mflix_comments: 0,
#     poster: 'https://m.media-amazon.com/images/M/MV5BNDFkNGY3Y2ItODA0MS00NWUwLWFjMTktZmEyYTQxZjFhMmZiXkEyXkFqcGdeQXVyNjQ2MjQ5NzM@._V1_SY1000_SX677_AL_.jpg',
#     title: 'Double Impact',
#     fullplot: 'Jean Claude Van Damme plays a dual role as Alex and Chad, twins separated at the death of their parents. Chad is raised by a family retainer in Paris, Alex becomes a petty crook in Hong Kong. Seeing a picture of Alex, Chad rejoins him and convinces him that his rival in Hong Kong is also the man who killed their parents. Alex is suspicious of Chad, especially when it comes to his girlfriend.',
#     languages: [ 'English' ],
#     released: ISODate("1991-08-09T00:00:00.000Z"),
#     directors: [ 'Sheldon Lettich' ],
#     writers: [
#       'Sheldon Lettich (screen story)',
#       'Jean-Claude Van Damme (screen story)',
#       'Steve Meerson (screen story)',
#       'Peter Krikes (screen story)',
#       'Sheldon Lettich (screenplay)',
#       'Jean-Claude Van Damme (screenplay)'
#     ],
#     awards: { wins: 0, nominations: 1, text: '1 nomination.' },
#     lastupdated: '2015-08-18 00:49:59.657000000',
#     year: 1991,
#     imdb: { rating: 5.4, votes: 26060, id: 101764 },
#     countries: [ 'USA' ],
#     type: 'movie',
#     tomatoes: {
#       viewer: { rating: 2.7, numReviews: 48625, meter: 42 },
#       dvd: ISODate("2001-02-06T00:00:00.000Z"),
#       critic: { rating: 3.8, numReviews: 14, meter: 14 },
#       lastUpdated: ISODate("2015-08-23T18:14:11.000Z"),
#       rotten: 12,
#       production: 'Sony Pictures Home Entertainment',
#       fresh: 2
#     }
#   },
#   {
#     _id: ObjectId("573a1399f29313caabcec779"),
#     plot: "Two parallel stories about two identical women; one living in Poland, the other in France. They don't know each other, but their lives are nevertheless profoundly connected.",
#     genres: [ 'Drama', 'Fantasy', 'Music' ],
#     runtime: 98,
#     rated: 'R',
#     cast: [
#       'Irène Jacob',
#       'Halina Gryglaszewska',
#       'Kalina Jedrusik',
#       'Aleksander Bardini'
#     ],
#     poster: 'https://m.media-amazon.com/images/M/MV5BNDJmMTRlMWEtNDFiMi00MDI1LWFkMWYtOWQzZGM1MTZkYTMyXkEyXkFqcGdeQXVyNzMzNzY1OTQ@._V1_SY1000_SX677_AL_.jpg',
#     title: 'The Double Life of Veronique',
#     fullplot: "Weronika lives in Poland. Vèronique lives in Paris. They don't know each other. Weronika gets a place in a music school, works hard, but collapses and dies on her first performance. At this point, Vèronique's life seems to take a turn and she decides not to be a singer...",
#     languages: [ 'French', 'Polish', 'Italian' ],
#     released: ISODate("1991-11-22T00:00:00.000Z"),
#     directors: [ 'Krzysztof Kieslowski' ],
#     writers: [ 'Krzysztof Kieslowski', 'Krzysztof Piesiewicz' ],
#     awards: {
#       wins: 9,
#       nominations: 7,
#       text: 'Nominated for 1 Golden Globe. Another 8 wins & 7 nominations.'
#     },
#     lastupdated: '2015-09-07 00:04:23.620000000',
#     year: 1991,
#     imdb: { rating: 7.9, votes: 25210, id: 101765 },
#     countries: [ 'France', 'Poland', 'Norway' ],
#     type: 'movie',
#     tomatoes: {
#       viewer: { rating: 4.2, numReviews: 19803, meter: 92 },
#       dvd: ISODate("2006-11-21T00:00:00.000Z"),
#       critic: { rating: 7.6, numReviews: 26, meter: 85 },
#       lastUpdated: ISODate("2015-08-22T18:26:07.000Z"),
#       rotten: 4,
#       production: 'Criterion Collection',
#       fresh: 22
#     },
#     num_mflix_comments: 0
#   },
#   {
#     _id: ObjectId("573a1399f29313caabcec78e"),
#     plot: "This slow-paced gem is about the civilizing influence of Italy on beleaguered Londoners both male and female and has its own civilizing influence on the viewer. It's almost like taking a ...",
#     genres: [ 'Drama' ],
#     runtime: 95,
#     rated: 'PG',
#     cast: [
#       'Josie Lawrence',
#       'Miranda Richardson',
#       'Alfred Molina',
#       'Neville Phillips'
#     ],
#     poster: 'https://m.media-amazon.com/images/M/MV5BMTU3Nzc4Mjc3MV5BMl5BanBnXkFtZTcwNjMzMzU1MQ@@._V1_SY1000_SX677_AL_.jpg',
#     title: 'Enchanted April',
#     fullplot: "This slow-paced gem is about the civilizing influence of Italy on beleaguered Londoners both male and female and has its own civilizing influence on the viewer. It's almost like taking a little mini-trip to Italy, a gorgeously filmed enchantment.",
#     languages: [ 'English', 'Italian' ],
#     released: ISODate("1992-04-05T00:00:00.000Z"),
#     directors: [ 'Mike Newell' ],
#     writers: [ 'Elizabeth von Arnim (novel)', 'Peter Barnes' ],
#     awards: {
#       wins: 9,
#       nominations: 3,
#       text: 'Nominated for 3 Oscars. Another 6 wins & 3 nominations.'
#     },
#     lastupdated: '2015-09-10 17:13:25.633000000',
#     year: 1991,
#     imdb: { rating: 7.4, votes: 4858, id: 101811 },
#     countries: [ 'UK' ],
#     type: 'movie',
#     tomatoes: {
#       viewer: { rating: 3.9, numReviews: 7559, meter: 83 },
#       dvd: ISODate("2009-05-05T00:00:00.000Z"),
#       critic: { rating: 7, numReviews: 28, meter: 82 },
#       lastUpdated: ISODate("2015-09-17T17:03:46.000Z"),
#       consensus: "Mike Newell's adaptation of Elizabeth von Arnim's moves at a more generous pace than the 1935 version, allowing excellent performances from Miranda Richardson and Joan Plowright to flourish.",
#       rotten: 5,
#       production: 'Miramax',
#       fresh: 23
#     },
#     num_mflix_comments: 0
#   },
#   {
#     _id: ObjectId("573a1399f29313caabcec7b2"),
#     plot: 'Just after WW2, an American takes a railway job in Germany, but finds his position politically sensitive with various people trying to use him.',
#     genres: [ 'Drama' ],
#     runtime: 112,
#     rated: 'R',
#     cast: [
#       'Jean-Marc Barr',
#       'Barbara Sukowa',
#       'Udo Kier',
#       'Ernst-Hugo Jèregèrd'
#     ],
#     num_mflix_comments: 1,
#     poster: 'https://m.media-amazon.com/images/M/MV5BNjJiZjIwMTItZDE4Ny00ZTdhLWI2ODMtYzhhNWJhODE1NGRkXkEyXkFqcGdeQXVyMjgyNjk3MzE@._V1_SY1000_SX677_AL_.jpg',
#     title: 'Europa',
#     fullplot: "An American of German descent arrives in post-war Germany 1945. His uncle gets him a job on the Zentropa train line as a sleeping car conductor. The American's wish is to be neutral to the ongoing purges of loyalists by the Allied forces and do what he can to help a hurting country, but he finds himself being used by both the Americans and the influential family that owns the railroad. After falling in love with the railroad magnate's daughter, he finds that he can't remain neutral and must make some difficult choices.",
#     languages: [ 'English', 'German' ],
#     released: ISODate("1991-06-27T00:00:00.000Z"),
#     directors: [ 'Lars von Trier' ],
#     writers: [ 'Lars von Trier', 'Niels Vèrsel' ],
#     awards: { wins: 16, nominations: 4, text: '16 wins & 4 nominations.' },
#     lastupdated: '2015-09-14 05:38:10.387000000',
#     year: 1991,
#     imdb: { rating: 7.7, votes: 14974, id: 101829 },
#     countries: [
#       'Spain',
#       'Denmark',
#       'Sweden',
#       'France',
#       'Germany',
#       'Switzerland'
#     ],
#     type: 'movie',
#     tomatoes: {
#       viewer: { rating: 4, numReviews: 6090, meter: 89 },
#       dvd: ISODate("2003-04-08T00:00:00.000Z"),
#       critic: { rating: 7.3, numReviews: 13, meter: 85 },
#       lastUpdated: ISODate("2015-07-30T19:29:27.000Z"),
#       rotten: 2,
#       production: 'Criterion Collection',
#       fresh: 11
#     }
#   },
#   {
#     _id: ObjectId("573a1399f29313caabcec7b8"),
#     plot: 'John Travolta is a downtrodden single father raising his daughter under difficult circumstances in Chicago. The young girl comes upon and then nurses a wounded Doberman used for fighting, ...',
#     genres: [ 'Drama' ],
#     runtime: 95,
#     rated: 'PG-13',
#     cast: [ 'John Travolta', 'Ellie Raab', 'Tito Larriva', 'Richard Edson' ],
#     num_mflix_comments: 0,
#     poster: 'https://m.media-amazon.com/images/M/MV5BYzdhYTU0MDMtZTI3Zi00MGJiLWI3N2UtNTk1N2Q3OTY4NmRkXkEyXkFqcGdeQXVyMTQxNzMzNDI@._V1_SY1000_SX677_AL_.jpg',
#     title: 'Eyes of an Angel',
#     fullplot: 'John Travolta is a downtrodden single father raising his daughter under difficult circumstances in Chicago. The young girl comes upon and then nurses a wounded Doberman used for fighting, back to health. Duped by underworld types he was working as a courier for, father and daughter leave the dog and flee cross-country to Los Angeles with both canine and mobsters in pursuit.',
#     languages: [ 'English' ],
#     released: ISODate("1991-06-29T00:00:00.000Z"),
#     directors: [ 'Robert Harmon' ],
#     writers: [ 'Robert Stitzel' ],
#     awards: { wins: 0, nominations: 1, text: '1 nomination.' },
#     lastupdated: '2015-08-05 00:46:07.680000000',
#     year: 1991,
#     imdb: { rating: 5.2, votes: 795, id: 101844 },
#     countries: [ 'USA' ],
#     type: 'movie',
#     tomatoes: {
#       viewer: { rating: 3.5, numReviews: 1071, meter: 55 },
#       dvd: ISODate("2002-10-22T00:00:00.000Z"),
#       production: 'Live Home Video',
#       lastUpdated: ISODate("2015-08-15T18:17:16.000Z")
#     }
#   },
#   {
#     _id: ObjectId("573a1399f29313caabcec7d3"),
#     plot: "With his oldest daughter's wedding approaching, a father finds himself reluctant to let go.",
#     genres: [ 'Comedy' ],
#     runtime: 105,
#     metacritic: 51,
#     rated: 'PG',
#     cast: [
#       'Steve Martin',
#       'Diane Keaton',
#       'Kimberly Williams-Paisley',
#       'Kieran Culkin'
#     ],
#     poster: 'https://m.media-amazon.com/images/M/MV5BYzM0YzBmMTUtN2RmZS00YWY5LWFkZTMtMjM1OWU3Nzk4ZjI1L2ltYWdlL2ltYWdlXkEyXkFqcGdeQXVyNDk3NzU2MTQ@._V1_SY1000_SX677_AL_.jpg',
#     title: 'Father of the Bride',
#     fullplot: 'In this remake of the Spencer Tracy classic, George and Nina Banks are the parents of young soon-to-be-wed Annie. George is a nervous father unready to face the fact that his little girl is now a woman. The preparations for the extravagant wedding provide additional comic moments.',
#     languages: [ 'English' ],
#     released: ISODate("1991-12-20T00:00:00.000Z"),
#     directors: [ 'Charles Shyer' ],
#     writers: [
#       'Frances Goodrich (screenplay)',
#       'Albert Hackett (screenplay)',
#       'Nancy Meyers (screenplay)',
#       'Charles Shyer (screenplay)'
#     ],
#     awards: { wins: 1, nominations: 4, text: '1 win & 4 nominations.' },
#     lastupdated: '2015-08-31 00:21:03.483000000',
#     year: 1991,
#     imdb: { rating: 6.4, votes: 51743, id: 101862 },
#     countries: [ 'USA' ],
#     type: 'movie',
#     tomatoes: {
#       viewer: { rating: 3.2, numReviews: 374720, meter: 70 },
#       dvd: ISODate("1999-04-20T00:00:00.000Z"),
#       critic: { rating: 6, numReviews: 41, meter: 73 },
#       lastUpdated: ISODate("2015-09-12T17:34:06.000Z"),
#       consensus: "While it doesn't quite hit the heights of the original, this remake of the 1950 classic is pleasantly enjoyable, thanks in large part to winning performances from Steve Martin and Martin Short.",
#       rotten: 11,
#       production: 'Touchstone Pictures',
#       fresh: 30
#     },
#     num_mflix_comments: 0
#   },
#   {
#     _id: ObjectId("573a1399f29313caabcec7f8"),
#     plot: 'Danny has been sent to boarding school, in this sequel to The Year My Voice Broke. Against a backdrop of bullying and sadistic teachers Danny strikes up an affair with an African girl, ...',
#     genres: [ 'Drama', 'Romance' ],
#     runtime: 99,
#     rated: 'R',
#     cast: [
#       'Noah Taylor',
#       'Thandie Newton',
#       'Nicole Kidman',
#       'Bartholomew Rose'
#     ],
#     poster: 'https://m.media-amazon.com/images/M/MV5BZDY3OGU2YmYtYjdkMC00YzNiLWJiYzQtMmU2NjA0YjBiMjBjL2ltYWdlXkEyXkFqcGdeQXVyMTQxNzMzNDI@._V1_SY1000_SX677_AL_.jpg',
#     title: 'Flirting',
#     fullplot: "Danny has been sent to boarding school, in this sequel to The Year My Voice Broke. Against a backdrop of bullying and sadistic teachers Danny strikes up an affair with an African girl, Thandiwe, studying at a nearby girl's school. Their affair blossoms while everyone tries to stop it. Nicole Kidman also appears as a sexually repressed senior at Thandiwe's school.",
#     languages: [ 'English' ],
#     released: ISODate("1992-11-14T00:00:00.000Z"),
#     directors: [ 'John Duigan' ],
#     writers: [ 'John Duigan' ],
#     awards: { wins: 5, nominations: 3, text: '5 wins & 3 nominations.' },
#     lastupdated: '2015-09-03 00:30:02.523000000',
#     year: 1991,
#     imdb: { rating: 7.3, votes: 4658, id: 101898 },
#     countries: [ 'Australia' ],
#     type: 'movie',
#     tomatoes: {
#       website: 'http://www.princessmovie.com',
#       viewer: { rating: 3.4, numReviews: 5647, meter: 76 },
#       dvd: ISODate("2002-09-17T00:00:00.000Z"),
#       critic: { rating: 7.3, numReviews: 24, meter: 96 },
#       lastUpdated: ISODate("2015-09-12T18:23:26.000Z"),
#       consensus: 'A terrific follow-up to The Year My Voice Broke, Flirting is a teen movie worth watching, thanks to emotionally engaging performances and an endearing script.',
#       rotten: 1,
#       production: 'Trimark',
#       fresh: 23
#     },
#     num_mflix_comments: 0
#   }
# ]
# Type "it" for more

# %% [markdown]
# ## Aggregation Stages
#
# As previously mentioned, the aggregation framework accepts as an arugment an array of `stages`. There are many types of stages, which all have their own associated use and syntax. Memorizing / knowing some of the most common stages is very important to being a certified MongoDB developer.
#
# - `$match`: Basically the same as a standard MQL query
# - `$project`: Similar to a standard MQL projection
# - `$limit`: limiting the results of a stage
# - `$out`: Persisting the results of an aggregation to another collection
# - `$lookup`: Similar to a SQL Join, incorporating data from another collection in the aggregation
# - `$set`: for modifying documents within an aggregation query
# - `$unwind`: to manipulate array values
# - `$group`: to group and create averages, summaries, etc
# - `$search`: To use a MongoDB Atlas Search index to perform a lucene based search. More on this later.
#
# A few other notes:
#
# - the aggregation framework allows a developer to access data within a document by using `$` syntax
# - there are a lot of stages. Although the above list covers most of them, I encourage you to [check them all out here](https://www.mongodb.com/docs/manual/reference/operator/aggregation-pipeline/)
#
# Let's take a look now at some aggregations in action:

# %%
aggString = "db.movies.aggregate([{\\$match:{year:1991}},{\\$set:{'plot':1,'firstCast':{\\$first:'\\$cast'}}},{\\$limit:1}])"

print(aggString.replace("\\", ""))
print("")

# !mongosh {mongoDB_connection_string} --quiet  --username {mongoDB_username} -p {mongoDB_password} \
--eval "use sample_mflix" \
--eval """{aggString}"""
# Out:
# db.movies.aggregate([{$match:{year:1991}},{$set:{'plot':1,'firstCast':{$first:'$cast'}}},{$limit:1}])
#
#  [
#   {
#     _id: ObjectId('573a1398f29313caabcead6a'),
#     plot: 1,
#     genres: [ 'Drama', 'Romance' ],
#     runtime: 110,
#     cast: [
#       'Ingrid Thulin',
#       'Dado Ruspoli',
#       'Enzo Cannavale',
#       'Nuccia Fumo'
#     ],
#     title: 'The House of Smiles',
#     fullplot: 'Adelina, a former "Miss Smiles" beauty queen, is a resident at a senior citizen retirement home. Her joie de vie and unfaded beauty make her attractive to the male residents, especially Andrea, a dapper and charming but married septuagenarian. Their initial mutual attraction evolves into physical desire, but their families and the conservative culture of the institution conspire against their consummating their love.',
#     languages: [ 'Italian', 'French' ],
#     released: ISODate('1991-03-01T00:00:00.000Z'),
#     directors: [ 'Marco Ferreri' ],
#     writers: [ 'Liliane Betti', 'Marco Ferreri', 'Antonino Marino' ],
#     awards: { wins: 1, nominations: 7, text: '1 win & 7 nominations.' },
#     lastupdated: '2015-08-13 00:06:59.537000000',
#     year: 1991,
#     imdb: { rating: 6.6, votes: 133, id: 94841 },
#     countries: [ 'Italy' ],
#     type: 'movie',
#     tomatoes: {
#       viewer: { rating: 3, numReviews: 55, meter: 75 },
#       dvd: ISODate('2008-08-19T00:00:00.000Z'),
#       lastUpdated: ISODate('2015-05-26T18:10:45.000Z')
#     },
#     num_mflix_comments: 0,
#     firstCast: 'Ingrid Thulin'
#   }
# ]

# %% [markdown]
# Let's talk about this aggregration:
#
# First, we performed a `$match` on movies where `{year:1991}`. Keep in mind this can be any filter, such as `$gte` or `$in`
#
# Then, the results of the previous stage (movies that are from 1991) _enters_ the `$set` stage.
#
# In this stage, we assign the value of 1 to the `plot` field. So in this case, it acts as an update
#
# In the same `$set` stage, we create a new k:v pair called `firstCast` amd the value of that field is the first element of the `cast` array. Note how we use the `$` syntax to tell the query that we are referring to the `cast` field, not a string "cast"
#
# we then limit the result to 1 to make it easier to read.
#
# Note that each stage has its own associated syntax. For example, the `$match` stage accepts a filter, where the `$limit` stage accepts an integer
#
# Let's extend the same aggregation with a `$out`

# %%
aggString = "db.movies.aggregate([{\\$match:{year:1991}},{\\$set:{'plot':1,'firstCast':{\\$first:'\\$cast'}}},{\\$limit:1},{\\$out:'outTest'}])"

print(aggString.replace("\\", ""))
print("")

# !mongosh {mongoDB_connection_string} --quiet  --username {mongoDB_username} -p {mongoDB_password} \
--eval "use sample_mflix" \
--eval """{aggString}"""
# Out:
# db.movies.aggregate([{$match:{year:1991}},{$set:{'plot':1,'firstCast':{$first:'$cast'}}},{$limit:1},{$out:'outTest'}])

# %%
readString = "db.outTest.find()"

print(readString.replace("\\", ""))
print("")

# !mongosh {mongoDB_connection_string} --quiet  --username {mongoDB_username} -p {mongoDB_password} \
--eval "use sample_mflix" \
--eval """{readString}"""
# Out:
# db.outTest.find()
#
#  [
#   {
#     _id: ObjectId('573a1398f29313caabcead6a'),
#     plot: 1,
#     genres: [ 'Drama', 'Romance' ],
#     runtime: 110,
#     cast: [
#       'Ingrid Thulin',
#       'Dado Ruspoli',
#       'Enzo Cannavale',
#       'Nuccia Fumo'
#     ],
#     title: 'The House of Smiles',
#     fullplot: 'Adelina, a former "Miss Smiles" beauty queen, is a resident at a senior citizen retirement home. Her joie de vie and unfaded beauty make her attractive to the male residents, especially Andrea, a dapper and charming but married septuagenarian. Their initial mutual attraction evolves into physical desire, but their families and the conservative culture of the institution conspire against their consummating their love.',
#     languages: [ 'Italian', 'French' ],
#     released: ISODate('1991-03-01T00:00:00.000Z'),
#     directors: [ 'Marco Ferreri' ],
#     writers: [ 'Liliane Betti', 'Marco Ferreri', 'Antonino Marino' ],
#     awards: { wins: 1, nominations: 7, text: '1 win & 7 nominations.' },
#     lastupdated: '2015-08-13 00:06:59.537000000',
#     year: 1991,
#     imdb: { rating: 6.6, votes: 133, id: 94841 },
#     countries: [ 'Italy' ],
#     type: 'movie',
#     tomatoes: {
#       viewer: { rating: 3, numReviews: 55, meter: 75 },
#       dvd: ISODate('2008-08-19T00:00:00.000Z'),
#       lastUpdated: ISODate('2015-05-26T18:10:45.000Z')
#     },
#     num_mflix_comments: 0,
#     firstCast: 'Ingrid Thulin'
#   }
# ]

# %% [markdown]
# Note that the result of `$out` is not a set of documents. If you were to run this from the shell, the output would be a result object specifying if the aggregation was successful. `$out` completely rewrites the target collection. For an append workload, the alternative `$merge` stage must be used.
#
# **unwinding and grouping**
#
# Consider the following aggregations:

# %%
aggString = "db.movies.aggregate([{\\$limit:10},{\\$project:{title:1,genres:1,runtime:1}}])"

print(aggString.replace("\\", ""))
print("")

# !mongosh {mongoDB_connection_string} --quiet  --username {mongoDB_username} -p {mongoDB_password} \
--eval "use sample_mflix" \
--eval """{aggString}"""
# Out:
# db.movies.aggregate([{$limit:10},{$project:{title:1,genres:1,runtime:1}}])
#
#  [
#   {
#     _id: ObjectId('573a1390f29313caabcd42e8'),
#     genres: [ 'Short', 'Western' ],
#     runtime: 11,
#     title: 'The Great Train Robbery'
#   },
#   {
#     _id: ObjectId('573a1390f29313caabcd446f'),
#     genres: [ 'Short', 'Drama' ],
#     runtime: 14,
#     title: 'A Corner in Wheat'
#   },
#   {
#     _id: ObjectId('573a1390f29313caabcd4803'),
#     genres: [ 'Animation', 'Short', 'Comedy' ],
#     runtime: 7,
#     title: 'Winsor McCay, the Famous Cartoonist of the N.Y. Herald and His Moving Comics'
#   },
#   {
#     _id: ObjectId('573a1390f29313caabcd4eaf'),
#     genres: [ 'Crime', 'Drama' ],
#     runtime: 88,
#     title: 'Traffic in Souls'
#   },
#   {
#     _id: ObjectId('573a1390f29313caabcd50e5'),
#     genres: [ 'Animation', 'Short', 'Comedy' ],
#     runtime: 12,
#     title: 'Gertie the Dinosaur'
#   },
#   {
#     _id: ObjectId('573a1390f29313caabcd516c'),
#     genres: [ 'Drama', 'History' ],
#     runtime: 65,
#     title: 'In the Land of the Head Hunters'
#   },
#   {
#     _id: ObjectId('573a1390f29313caabcd5293'),
#     genres: [ 'Action' ],
#     runtime: 199,
#     title: 'The Perils of Pauline'
#   },
#   {
#     _id: ObjectId('573a1390f29313caabcd56df'),
#     genres: [ 'Drama' ],
#     runtime: 78,
#     title: 'The Italian'
#   },
#   {
#     _id: ObjectId('573a1390f29313caabcd587d'),
#     genres: [ 'Biography', 'Crime', 'Drama' ],
#     runtime: 72,
#     title: 'Regeneration'
#   },
#   {
#     _id: ObjectId('573a1390f29313caabcd5a93'),
#     genres: [ 'Drama' ],
#     runtime: 78,
#     title: 'Civilization'
#   }
# ]

# %%
aggString = "db.movies.aggregate([{\\$limit:10},{\\$project:{title:1,genres:1,runtime:1}},{\\$unwind:{path:'\\$genres'}}])"

print(aggString.replace("\\", ""))
print("")

# !mongosh {mongoDB_connection_string} --quiet  --username {mongoDB_username} -p {mongoDB_password} \
--eval "use sample_mflix" \
--eval """{aggString}"""
# Out:
# db.movies.aggregate([{$limit:10},{$project:{title:1,genres:1,runtime:1}},{$unwind:{path:'$genres'}}])
#
#  [
#   {
#     _id: ObjectId('573a1390f29313caabcd42e8'),
#     genres: 'Short',
#     runtime: 11,
#     title: 'The Great Train Robbery'
#   },
#   {
#     _id: ObjectId('573a1390f29313caabcd42e8'),
#     genres: 'Western',
#     runtime: 11,
#     title: 'The Great Train Robbery'
#   },
#   {
#     _id: ObjectId('573a1390f29313caabcd446f'),
#     genres: 'Short',
#     runtime: 14,
#     title: 'A Corner in Wheat'
#   },
#   {
#     _id: ObjectId('573a1390f29313caabcd446f'),
#     genres: 'Drama',
#     runtime: 14,
#     title: 'A Corner in Wheat'
#   },
#   {
#     _id: ObjectId('573a1390f29313caabcd4803'),
#     genres: 'Animation',
#     runtime: 7,
#     title: 'Winsor McCay, the Famous Cartoonist of the N.Y. Herald and His Moving Comics'
#   },
#   {
#     _id: ObjectId('573a1390f29313caabcd4803'),
#     genres: 'Short',
#     runtime: 7,
#     title: 'Winsor McCay, the Famous Cartoonist of the N.Y. Herald and His Moving Comics'
#   },
#   {
#     _id: ObjectId('573a1390f29313caabcd4803'),
#     genres: 'Comedy',
#     runtime: 7,
#     title: 'Winsor McCay, the Famous Cartoonist of the N.Y. Herald and His Moving Comics'
#   },
#   {
#     _id: ObjectId('573a1390f29313caabcd4eaf'),
#     genres: 'Crime',
#     runtime: 88,
#     title: 'Traffic in Souls'
#   },
#   {
#     _id: ObjectId('573a1390f29313caabcd4eaf'),
#     genres: 'Drama',
#     runtime: 88,
#     title: 'Traffic in Souls'
#   },
#   {
#     _id: ObjectId('573a1390f29313caabcd50e5'),
#     genres: 'Animation',
#     runtime: 12,
#     title: 'Gertie the Dinosaur'
#   },
#   {
#     _id: ObjectId('573a1390f29313caabcd50e5'),
#     genres: 'Short',
#     runtime: 12,
#     title: 'Gertie the Dinosaur'
#   },
#   {
#     _id: ObjectId('573a1390f29313caabcd50e5'),
#     genres: 'Comedy',
#     runtime: 12,
#     title: 'Gertie the Dinosaur'
#   },
#   {
#     _id: ObjectId('573a1390f29313caabcd516c'),
#     genres: 'Drama',
#     runtime: 65,
#     title: 'In the Land of the Head Hunters'
#   },
#   {
#     _id: ObjectId('573a1390f29313caabcd516c'),
#     genres: 'History',
#     runtime: 65,
#     title: 'In the Land of the Head Hunters'
#   },
#   {
#     _id: ObjectId('573a1390f29313caabcd5293'),
#     genres: 'Action',
#     runtime: 199,
#     title: 'The Perils of Pauline'
#   },
#   {
#     _id: ObjectId('573a1390f29313caabcd56df'),
#     genres: 'Drama',
#     runtime: 78,
#     title: 'The Italian'
#   },
#   {
#     _id: ObjectId('573a1390f29313caabcd587d'),
#     genres: 'Biography',
#     runtime: 72,
#     title: 'Regeneration'
#   },
#   {
#     _id: ObjectId('573a1390f29313caabcd587d'),
#     genres: 'Crime',
#     runtime: 72,
#     title: 'Regeneration'
#   },
#   {
#     _id: ObjectId('573a1390f29313caabcd587d'),
#     genres: 'Drama',
#     runtime: 72,
#     title: 'Regeneration'
#   },
#   {
#     _id: ObjectId('573a1390f29313caabcd5a93'),
#     genres: 'Drama',
#     runtime: 78,
#     title: 'Civilization'
#   }
# ]
# Type "it" for more

# %%
aggString = "db.movies.aggregate([{\\$limit:10},{\\$project:{title:1,genres:1,runtime:1}},{\\$unwind:{path:'\\$genres'}},{\\$group:{_id:'\\$genres',listOfMovies:{\\$push:'\\$title'},avgRuntime:{\\$avg:'\\$runtime'}}}])"

print(aggString.replace("\\", ""))
print("")

# !mongosh {mongoDB_connection_string} --quiet  --username {mongoDB_username} -p {mongoDB_password} \
--eval "use sample_mflix" \
--eval """{aggString}"""
# Out:
# db.movies.aggregate([{$limit:10},{$project:{title:1,genres:1,runtime:1}},{$unwind:{path:'$genres'}},{$group:{_id:'$genres',listOfMovies:{$push:'$title'},avgRuntime:{$avg:'$runtime'}}}])
#
#  [
#   {
#     _id: 'Animation',
#     listOfMovies: [
#       'Winsor McCay, the Famous Cartoonist of the N.Y. Herald and His Moving Comics',
#       'Gertie the Dinosaur'
#     ],
#     avgRuntime: 9.5
#   },
#   {
#     _id: 'Action',
#     listOfMovies: [ 'The Perils of Pauline' ],
#     avgRuntime: 199
#   },
#   {
#     _id: 'Drama',
#     listOfMovies: [
#       'A Corner in Wheat',
#       'Traffic in Souls',
#       'In the Land of the Head Hunters',
#       'The Italian',
#       'Regeneration',
#       'Civilization'
#     ],
#     avgRuntime: 65.83333333333333
#   },
#   {
#     _id: 'History',
#     listOfMovies: [ 'In the Land of the Head Hunters' ],
#     avgRuntime: 65
#   },
#   {
#     _id: 'Western',
#     listOfMovies: [ 'The Great Train Robbery' ],
#     avgRuntime: 11
#   },
#   {
#     _id: 'Comedy',
#     listOfMovies: [
#       'Winsor McCay, the Famous Cartoonist of the N.Y. Herald and His Moving Comics',
#       'Gertie the Dinosaur'
#     ],
#     avgRuntime: 9.5
#   },
#   {
#     _id: 'Biography',
#     listOfMovies: [ 'Regeneration' ],
#     avgRuntime: 72
#   },
#   {
#     _id: 'Crime',
#     listOfMovies: [ 'Traffic in Souls', 'Regeneration' ],
#     avgRuntime: 80
#   },
#   {
#     _id: 'Short',
#     listOfMovies: [
#       'The Great Train Robbery',
#       'A Corner in Wheat',
#       'Winsor McCay, the Famous Cartoonist of the N.Y. Herald and His Moving Comics',
#       'Gertie the Dinosaur'
#     ],
#     avgRuntime: 11
#   }
# ]

# %% [markdown]
# The previous 3 aggregations were built on each other to show various stages:
#
# in the first aggregation, we use `$limit` and `$project`
#
# in the second agg, we use `$unwind` to break apart the `genres` array. Notice how the result set has multiple entries per movie. Note the fact that unwind accepts as an argument an object that looks like `{path:'$genres'}`. That is part of the `$unwind` syntax (there are more arguments for `$unwind` but they are out of the scope of this session)
#
# In the third agg, we use those unwound movie-genre records, and then `$group` by the genre. This stage accepts an `_id` field (which is the field we group on) and all the other fields accept an `accumulator` such as `$push` or `$avg`.
#
# Note that the same command can mean different things in different contexts. Take for example `$push`. If this is part of an update statement (look back at session 2 for examples of this), it signifies to the server to insert an element into an array. When it is used in the context of an accumulator, it signifies to the server to make arrays based on grouped keys.
#
# Here's one more aggregation:

# %%
aggString = "db.movies.aggregate([{\\$match:{title:'The Black Pirate'}},{\\$lookup:{from:'comments',localField:'_id',foreignField:'movie_id',as:'comments'}}])"

print(aggString.replace("\\", ""))
print("")

# !mongosh {mongoDB_connection_string} --quiet  --username {mongoDB_username} -p {mongoDB_password} \
--eval "use sample_mflix" \
--eval """{aggString}"""
# Out:
# db.movies.aggregate([{$match:{title:'The Black Pirate'}},{$lookup:{from:'comments',localField:'_id',foreignField:'movie_id',as:'comments'}}])
#
#  [
#   {
#     _id: ObjectId('573a1391f29313caabcd8268'),
#     plot: "Seeking revenge, an athletic young man joins the pirate band responsible for his father's death.",
#     genres: [ 'Adventure', 'Action' ],
#     runtime: 88,
#     cast: [ 'Billie Dove', 'Tempe Pigott', 'Donald Crisp', 'Sam De Grasse' ],
#     num_mflix_comments: 1,
#     poster: 'https://m.media-amazon.com/images/M/MV5BMzU0NDkyMjEzMV5BMl5BanBnXkFtZTgwMTcyMzEyMjE@._V1_SY1000_SX677_AL_.jpg',
#     title: 'The Black Pirate',
#     fullplot: 'A nobleman vows to avenge the death of his father at the hands of pirates. To this end he infiltrates the pirate band. Acting in character he is instrumental in the capture of a ship, but things are complicated when he finds that there is a young woman on board whom he wishes to protect from the threat of rape.',
#     countries: [ 'USA' ],
#     released: ISODate('1926-03-08T00:00:00.000Z'),
#     directors: [ 'Albert Parker' ],
#     writers: [ 'Douglas Fairbanks (story)', 'Jack Cunningham (adapted by)' ],
#     awards: { wins: 1, nominations: 0, text: '1 win.' },
#     lastupdated: '2015-08-22 01:10:11.970000000',
#     year: 1926,
#     imdb: { rating: 7.2, votes: 1146, id: 16654 },
#     type: 'movie',
#     tomatoes: {
#       viewer: { rating: 3.3, numReviews: 1390, meter: 70 },
#       dvd: ISODate('1999-10-12T00:00:00.000Z'),
#       critic: { rating: 8.1, numReviews: 9, meter: 100 },
#       lastUpdated: ISODate('2015-07-22T19:23:50.000Z'),
#       rotten: 0,
#       fresh: 9
#     },
#     comments: [
#       {
#         _id: ObjectId('5a9427648b0beebeb6957b86'),
#         name: 'Sansa Stark',
#         email: 'sophie_turner@gameofthron.es',
#         movie_id: ObjectId('573a1391f29313caabcd8268'),
#         text: 'Aliquam tempora suscipit vero id. Natus nesciunt molestiae odio. Vel molestiae incidunt laborum fuga. Excepturi labore molestias dolor.',
#         date: ISODate('1996-10-07T18:10:43.000Z')
#       }
#     ]
#   }
# ]

# %% [markdown]
# The previous aggregation showed an example of a `$lookup`, which is like a SQL Join against another table (collection). In the example, we are joining `movies` with `comments` based on the movie's `_id` value
#
# ## Indexes
#
# ... Okay...
#
# So we're done talking about querying for a while.
#
# **IT IS INCREDIBLY IMPORTANT THAT YOU MEMORIZE THE CONTENT FROM THIS SESSION AND THE PAST SESSION. WHILE INDEXES ARE IMPORTANT FOR A MONGODB DEVELOPER, KNOWLEDGE OF MQL AND AGGREGATIONS MAKE UP 50% OF THE TEST'S CONTENT.**
#
# For any real use of MongoDB, it is required to make an index to support the most common queries. Before talking about MongoDB indexes, I will spend a bit discussing how the MongoDB server process _works_
#
# - CPU: Coordinates query parsing and query handling
# - RAM: contains indexes and data that is being "examined", as well as handling connections, managing transactions, cursors
# - SSD / "storage" / "disk": stores all data files
#
# Every time the server receives a query of a new "shape' (the inputs in the query), a background server process will determine the best index to use and store the "query plan" in memory.
#
# Documents need to be examined - the process of checking fields to see if they match the filter that is passed into the query. MongoDB does not have the ability to "examine" documents while they are in disk. Thus, all documents that _may_ satisfy the query will be "fetched" from disk into memory. An index allows the database to store fields in memory, and by using indexes we can avoid fetching many documents from disk to RAM.
#
# I should point out that fetching large amounts of documents from disk to RAM is a very slow operation that highly taxes available computer resources. It is beyond the scope of these sessions, but generally we should avoid large "scans"
#
# ... Okay...
#
# That's enough of the theoretical stuff for now.
#
# Here are some facts:
# - Indexes are defined at the collection level
# - Indexes can be created on individual fields, or multiple fields
# - For multiple field ("compound") indexes, the ordering matters
# - The _id field is always indexed
# - Indexes can be used to enforce uniqueness
# - administrative commands for creating indexes and removing indexes are not a focus for the developer exam.
#
# The best way to reason about indexes is to reason about them like a phone book. We will talk about this soon.
#
# Let's look at some basic commands regarding indexes:

# %%
idxString = "db.movies.getIndexes()"

print(idxString.replace("\\", ""))
print("")

# !mongosh {mongoDB_connection_string} --quiet  --username {mongoDB_username} -p {mongoDB_password} \
--eval "use sample_mflix" \
--eval """{idxString}"""
# Out:
# db.movies.getIndexes()
#
#  [
#   { v: 2, key: { _id: 1 }, name: '_id_' },
#   {
#     v: 2,
#     key: { _fts: 'text', _ftsx: 1 },
#     name: 'cast_text_fullplot_text_genres_text_title_text',
#     weights: { cast: 1, fullplot: 1, genres: 1, title: 1 },
#     default_language: 'english',
#     language_override: 'language',
#     textIndexVersion: 3
#   }
# ]

# %%
createString = "db.movies.createIndex({title:1})"
idxString = "db.movies.find({title:'Peter Pan'}).explain('executionStats')"

print(idxString.replace("\\", ""))
print("")

# !mongosh {mongoDB_connection_string} --quiet  --username {mongoDB_username} -p {mongoDB_password} \
--eval "use sample_mflix" \
--eval """{createString}""" \
--eval """{idxString}"""
# Out:
# db.movies.find({title:'Peter Pan'}).explain('executionStats')
#
#  {
#   explainVersion: '1',
#   queryPlanner: {
#     namespace: 'sample_mflix.movies',
#     indexFilterSet: false,
#     parsedQuery: { title: { '$eq': 'Peter Pan' } },
#     queryHash: '2495AF30',
#     planCacheKey: 'D2B6550E',
#     maxIndexedOrSolutionsReached: false,
#     maxIndexedAndSolutionsReached: false,
#     maxScansToExplodeReached: false,
#     winningPlan: {
#       stage: 'FETCH',
#       inputStage: {
#         stage: 'IXSCAN',
#         keyPattern: { title: 1 },
#         indexName: 'title_1',
#         isMultiKey: false,
#         multiKeyPaths: { title: [] },
#         isUnique: false,
#         isSparse: false,
#         isPartial: false,
#         indexVersion: 2,
#         direction: 'forward',
#         indexBounds: { title: [ '["Peter Pan", "Peter Pan"]' ] }
#       }
#     },
#     rejectedPlans: []
#   },
#   executionStats: {
#     executionSuccess: true,
#     nReturned: 5,
#     executionTimeMillis: 1,
#     totalKeysExamined: 5,
#     totalDocsExamined: 5,
#     executionStages: {
#       stage: 'FETCH',
#       nReturned: 5,
#       executionTimeMillisEstimate: 0,
#       works: 6,
#       advanced: 5,
#       needTime: 0,
#       needYield: 0,
#       saveState: 0,
#       restoreState: 0,
#       isEOF: 1,
#       docsExamined: 5,
#       alreadyHasObj: 0,
#       inputStage: {
#         stage: 'IXSCAN',
#         nReturned: 5,
#         executionTimeMillisEstimate: 0,
#         works: 6,
#         advanced: 5,
#         needTime: 0,
#         needYield: 0,
#         saveState: 0,
#         restoreState: 0,
#         isEOF: 1,
#         keyPattern: { title: 1 },
#         indexName: 'title_1',
#         isMultiKey: false,
#         multiKeyPaths: { title: [] },
#         isUnique: false,
#         isSparse: false,
#         isPartial: false,
#         indexVersion: 2,
#         direction: 'forward',
#         indexBounds: { title: [ '["Peter Pan", "Peter Pan"]' ] },
#         keysExamined: 5,
#         seeks: 1,
#         dupsTested: 0,
#         dupsDropped: 0
#       }
#     }
#   },
#   command: {
#     find: 'movies',
#     filter: { title: 'Peter Pan' },
#     '$db': 'sample_mflix'
#   },
#   serverInfo: {
#     host: 'ac-lti9mog-shard-00-02.0epnrpd.mongodb.net',
#     port: 27017,
#     version: '7.0.8',
#     gitVersion: 'c5d33e55ba38d98e2f48765ec4e55338d67a4a64'
#   },
#   serverParameters: {
#     internalQueryFacetBufferSizeBytes: 104857600,
#     internalQueryFacetMaxOutputDocSizeBytes: 104857600,
#     internalLookupStageIntermediateDocumentMaxSizeBytes: 16793600,
#     internalDocumentSourceGroupMaxMemoryBytes: 104857600,
#     internalQueryMaxBlockingSortMemoryUsageBytes: 33554432,
#     internalQueryProhibitBlockingMergeOnMongoS: 0,
#     internalQueryMaxAddToSetBytes: 104857600,
#     internalDocumentSourceSetWindowFieldsMaxMemoryBytes: 104857600,
#     internalQueryFrameworkControl: 'trySbeRestricted'
#   },
#   ok: 1,
#   '$clusterTime': {
#     clusterTime: Timestamp({ t: 1712775409, i: 39 }),
#     signature: {
#       hash: Binary.createFromBase64('XkhmjaR/KT2v3DsFRhkpKMeV6sc=', 0),
#       keyId: Long('7297225448235204610')
#     }
#   },
#   operationTime: Timestamp({ t: 1712775409, i: 39 })
# }

# %%
createString = "db.movies.createIndex({title:1})"
idxString = "db.movies.find({title:'Peter Pan',year:1924}).explain('executionStats')"

print(idxString.replace("\\", ""))
print("")

# !mongosh {mongoDB_connection_string} --quiet  --username {mongoDB_username} -p {mongoDB_password} \
--eval "use sample_mflix" \
--eval """{createString}""" \
--eval """{idxString}"""
# Out:
# db.movies.find({title:'Peter Pan',year:1924}).explain('executionStats')
#
#  {
#   explainVersion: '1',
#   queryPlanner: {
#     namespace: 'sample_mflix.movies',
#     indexFilterSet: false,
#     parsedQuery: {
#       '$and': [ { title: { '$eq': 'Peter Pan' } }, { year: { '$eq': 1924 } } ]
#     },
#     queryHash: '7A13949E',
#     planCacheKey: '58534009',
#     maxIndexedOrSolutionsReached: false,
#     maxIndexedAndSolutionsReached: false,
#     maxScansToExplodeReached: false,
#     winningPlan: {
#       stage: 'FETCH',
#       filter: { year: { '$eq': 1924 } },
#       inputStage: {
#         stage: 'IXSCAN',
#         keyPattern: { title: 1 },
#         indexName: 'title_1',
#         isMultiKey: false,
#         multiKeyPaths: { title: [] },
#         isUnique: false,
#         isSparse: false,
#         isPartial: false,
#         indexVersion: 2,
#         direction: 'forward',
#         indexBounds: { title: [ '["Peter Pan", "Peter Pan"]' ] }
#       }
#     },
#     rejectedPlans: []
#   },
#   executionStats: {
#     executionSuccess: true,
#     nReturned: 1,
#     executionTimeMillis: 0,
#     totalKeysExamined: 5,
#     totalDocsExamined: 5,
#     executionStages: {
#       stage: 'FETCH',
#       filter: { year: { '$eq': 1924 } },
#       nReturned: 1,
#       executionTimeMillisEstimate: 0,
#       works: 6,
#       advanced: 1,
#       needTime: 4,
#       needYield: 0,
#       saveState: 0,
#       restoreState: 0,
#       isEOF: 1,
#       docsExamined: 5,
#       alreadyHasObj: 0,
#       inputStage: {
#         stage: 'IXSCAN',
#         nReturned: 5,
#         executionTimeMillisEstimate: 0,
#         works: 6,
#         advanced: 5,
#         needTime: 0,
#         needYield: 0,
#         saveState: 0,
#         restoreState: 0,
#         isEOF: 1,
#         keyPattern: { title: 1 },
#         indexName: 'title_1',
#         isMultiKey: false,
#         multiKeyPaths: { title: [] },
#         isUnique: false,
#         isSparse: false,
#         isPartial: false,
#         indexVersion: 2,
#         direction: 'forward',
#         indexBounds: { title: [ '["Peter Pan", "Peter Pan"]' ] },
#         keysExamined: 5,
#         seeks: 1,
#         dupsTested: 0,
#         dupsDropped: 0
#       }
#     }
#   },
#   command: {
#     find: 'movies',
#     filter: { title: 'Peter Pan', year: 1924 },
#     '$db': 'sample_mflix'
#   },
#   serverInfo: {
#     host: 'ac-lti9mog-shard-00-02.0epnrpd.mongodb.net',
#     port: 27017,
#     version: '7.0.8',
#     gitVersion: 'c5d33e55ba38d98e2f48765ec4e55338d67a4a64'
#   },
#   serverParameters: {
#     internalQueryFacetBufferSizeBytes: 104857600,
#     internalQueryFacetMaxOutputDocSizeBytes: 104857600,
#     internalLookupStageIntermediateDocumentMaxSizeBytes: 16793600,
#     internalDocumentSourceGroupMaxMemoryBytes: 104857600,
#     internalQueryMaxBlockingSortMemoryUsageBytes: 33554432,
#     internalQueryProhibitBlockingMergeOnMongoS: 0,
#     internalQueryMaxAddToSetBytes: 104857600,
#     internalDocumentSourceSetWindowFieldsMaxMemoryBytes: 104857600,
#     internalQueryFrameworkControl: 'trySbeRestricted'
#   },
#   ok: 1,
#   '$clusterTime': {
#     clusterTime: Timestamp({ t: 1712775417, i: 14 }),
#     signature: {
#       hash: Binary.createFromBase64('k00PN9AYV7NAyqZMQnSOtTQRdfU=', 0),
#       keyId: Long('7297225448235204610')
#     }
#   },
#   operationTime: Timestamp({ t: 1712775417, i: 14 })
# }

# %%
createString = "db.movies.createIndex({title:1})"
idxString = "db.movies.find({runtime:111}).explain('executionStats')"

print(idxString.replace("\\", ""))
print("")

# !mongosh {mongoDB_connection_string} --quiet  --username {mongoDB_username} -p {mongoDB_password} \
--eval "use sample_mflix" \
--eval """{createString}""" \
--eval """{idxString}"""
# Out:
# db.movies.find({runtime:111}).explain('executionStats')
#
#  {
#   explainVersion: '1',
#   queryPlanner: {
#     namespace: 'sample_mflix.movies',
#     indexFilterSet: false,
#     parsedQuery: { runtime: { '$eq': 111 } },
#     queryHash: 'ADC785B0',
#     planCacheKey: 'ADC785B0',
#     maxIndexedOrSolutionsReached: false,
#     maxIndexedAndSolutionsReached: false,
#     maxScansToExplodeReached: false,
#     winningPlan: {
#       stage: 'COLLSCAN',
#       filter: { runtime: { '$eq': 111 } },
#       direction: 'forward'
#     },
#     rejectedPlans: []
#   },
#   executionStats: {
#     executionSuccess: true,
#     nReturned: 251,
#     executionTimeMillis: 24,
#     totalKeysExamined: 0,
#     totalDocsExamined: 21349,
#     executionStages: {
#       stage: 'COLLSCAN',
#       filter: { runtime: { '$eq': 111 } },
#       nReturned: 251,
#       executionTimeMillisEstimate: 9,
#       works: 21350,
#       advanced: 251,
#       needTime: 21098,
#       needYield: 0,
#       saveState: 21,
#       restoreState: 21,
#       isEOF: 1,
#       direction: 'forward',
#       docsExamined: 21349
#     }
#   },
#   command: { find: 'movies', filter: { runtime: 111 }, '$db': 'sample_mflix' },
#   serverInfo: {
#     host: 'ac-lti9mog-shard-00-02.0epnrpd.mongodb.net',
#     port: 27017,
#     version: '7.0.8',
#     gitVersion: 'c5d33e55ba38d98e2f48765ec4e55338d67a4a64'
#   },
#   serverParameters: {
#     internalQueryFacetBufferSizeBytes: 104857600,
#     internalQueryFacetMaxOutputDocSizeBytes: 104857600,
#     internalLookupStageIntermediateDocumentMaxSizeBytes: 16793600,
#     internalDocumentSourceGroupMaxMemoryBytes: 104857600,
#     internalQueryMaxBlockingSortMemoryUsageBytes: 33554432,
#     internalQueryProhibitBlockingMergeOnMongoS: 0,
#     internalQueryMaxAddToSetBytes: 104857600,
#     internalDocumentSourceSetWindowFieldsMaxMemoryBytes: 104857600,
#     internalQueryFrameworkControl: 'trySbeRestricted'
#   },
#   ok: 1,
#   '$clusterTime': {
#     clusterTime: Timestamp({ t: 1712775422, i: 17 }),
#     signature: {
#       hash: Binary.createFromBase64('sRYjX4oKGYzVpyROE2zFiabA3W8=', 0),
#       keyId: Long('7297225448235204610')
#     }
#   },
#   operationTime: Timestamp({ t: 1712775422, i: 17 })
# }

# %% [markdown]
# The first example is using `db.collection.getIndexes()` to print out the list of indexes for that collection.
#
# The next three examples use `db.collection.find().explain()` to show some sample outputs of explain plans.
#
# - the first `find()` has a filter that is completely covered by an index (notice the winning plan has a FETCH stage with no query parsing, fed by an IXSCAN)
# - the second has a filter that is partially covered by an index (FETCH with a filter)
# - the third has a filter which is not covered by any index (COLLSCAN)
#
# **Digging Deeper**
#
# Indexes can have a direction, indicated by 1, or -1.
#
# So far, all the indexes we have seen are on a single scalar field. The index is not required to be on a single field, OR on scalar fields.
#
# Indexes on array values are supported. These are often called "multi-key" indexes.
#
# Indexes on subdocuments are supported, however I suggest against using these. Instead use dot notation to index on fields of a subdocument.
#
# Most indexes use more than 1 field and are called **compound indexes**. This is an in depth concept and warrants further discussion.

# %%
createString = "db.movies.createIndex({cast:1})"
idxString = "db.movies.find({cast:'Brad Pitt'}).explain('executionStats')"

print(idxString.replace("\\", ""))
print("")

# !mongosh {mongoDB_connection_string} --quiet  --username {mongoDB_username} -p {mongoDB_password} \
--eval "use sample_mflix" \
--eval """{createString}""" \
--eval """{idxString}"""
# Out:
# db.movies.find({cast:'Brad Pitt'}).explain('executionStats')
#
#  {
#   explainVersion: '1',
#   queryPlanner: {
#     namespace: 'sample_mflix.movies',
#     indexFilterSet: false,
#     parsedQuery: { cast: { '$eq': 'Brad Pitt' } },
#     queryHash: '3C5871F0',
#     planCacheKey: '290FB354',
#     maxIndexedOrSolutionsReached: false,
#     maxIndexedAndSolutionsReached: false,
#     maxScansToExplodeReached: false,
#     winningPlan: {
#       stage: 'FETCH',
#       inputStage: {
#         stage: 'IXSCAN',
#         keyPattern: { cast: 1 },
#         indexName: 'cast_1',
#         isMultiKey: true,
#         multiKeyPaths: { cast: [ 'cast' ] },
#         isUnique: false,
#         isSparse: false,
#         isPartial: false,
#         indexVersion: 2,
#         direction: 'forward',
#         indexBounds: { cast: [ '["Brad Pitt", "Brad Pitt"]' ] }
#       }
#     },
#     rejectedPlans: []
#   },
#   executionStats: {
#     executionSuccess: true,
#     nReturned: 29,
#     executionTimeMillis: 1,
#     totalKeysExamined: 29,
#     totalDocsExamined: 29,
#     executionStages: {
#       stage: 'FETCH',
#       nReturned: 29,
#       executionTimeMillisEstimate: 1,
#       works: 30,
#       advanced: 29,
#       needTime: 0,
#       needYield: 0,
#       saveState: 0,
#       restoreState: 0,
#       isEOF: 1,
#       docsExamined: 29,
#       alreadyHasObj: 0,
#       inputStage: {
#         stage: 'IXSCAN',
#         nReturned: 29,
#         executionTimeMillisEstimate: 1,
#         works: 30,
#         advanced: 29,
#         needTime: 0,
#         needYield: 0,
#         saveState: 0,
#         restoreState: 0,
#         isEOF: 1,
#         keyPattern: { cast: 1 },
#         indexName: 'cast_1',
#         isMultiKey: true,
#         multiKeyPaths: { cast: [ 'cast' ] },
#         isUnique: false,
#         isSparse: false,
#         isPartial: false,
#         indexVersion: 2,
#         direction: 'forward',
#         indexBounds: { cast: [ '["Brad Pitt", "Brad Pitt"]' ] },
#         keysExamined: 29,
#         seeks: 1,
#         dupsTested: 29,
#         dupsDropped: 0
#       }
#     }
#   },
#   command: {
#     find: 'movies',
#     filter: { cast: 'Brad Pitt' },
#     '$db': 'sample_mflix'
#   },
#   serverInfo: {
#     host: 'ac-lti9mog-shard-00-02.0epnrpd.mongodb.net',
#     port: 27017,
#     version: '7.0.8',
#     gitVersion: 'c5d33e55ba38d98e2f48765ec4e55338d67a4a64'
#   },
#   serverParameters: {
#     internalQueryFacetBufferSizeBytes: 104857600,
#     internalQueryFacetMaxOutputDocSizeBytes: 104857600,
#     internalLookupStageIntermediateDocumentMaxSizeBytes: 16793600,
#     internalDocumentSourceGroupMaxMemoryBytes: 104857600,
#     internalQueryMaxBlockingSortMemoryUsageBytes: 33554432,
#     internalQueryProhibitBlockingMergeOnMongoS: 0,
#     internalQueryMaxAddToSetBytes: 104857600,
#     internalDocumentSourceSetWindowFieldsMaxMemoryBytes: 104857600,
#     internalQueryFrameworkControl: 'trySbeRestricted'
#   },
#   ok: 1,
#   '$clusterTime': {
#     clusterTime: Timestamp({ t: 1712775428, i: 49 }),
#     signature: {
#       hash: Binary.createFromBase64('xCv1Qi2IEvXSJHRP5YBKpDmEc8g=', 0),
#       keyId: Long('7297225448235204610')
#     }
#   },
#   operationTime: Timestamp({ t: 1712775428, i: 49 })
# }

# %%
createString = "db.movies.createIndex({imdb:1})"
dropString = "db.movies.dropIndex({'imdb.rating':1})"
idxString = "db.movies.find({'imdb.rating':6}).explain('executionStats')"

print(idxString.replace("\\", ""))
print("")

# !mongosh {mongoDB_connection_string} --quiet  --username {mongoDB_username} -p {mongoDB_password} \
--eval "use sample_mflix" \
--eval """{createString}""" \
--eval """{dropString}""" \
--eval """{idxString}"""
# Out:
# db.movies.find({'imdb.rating':6}).explain('executionStats')
#
#  {
#   explainVersion: '1',
#   queryPlanner: {
#     namespace: 'sample_mflix.movies',
#     indexFilterSet: false,
#     parsedQuery: { 'imdb.rating': { '$eq': 6 } },
#     queryHash: 'B8C7FF17',
#     planCacheKey: 'B8C7FF17',
#     maxIndexedOrSolutionsReached: false,
#     maxIndexedAndSolutionsReached: false,
#     maxScansToExplodeReached: false,
#     winningPlan: {
#       stage: 'COLLSCAN',
#       filter: { 'imdb.rating': { '$eq': 6 } },
#       direction: 'forward'
#     },
#     rejectedPlans: []
#   },
#   executionStats: {
#     executionSuccess: true,
#     nReturned: 521,
#     executionTimeMillis: 26,
#     totalKeysExamined: 0,
#     totalDocsExamined: 21349,
#     executionStages: {
#       stage: 'COLLSCAN',
#       filter: { 'imdb.rating': { '$eq': 6 } },
#       nReturned: 521,
#       executionTimeMillisEstimate: 3,
#       works: 21350,
#       advanced: 521,
#       needTime: 20828,
#       needYield: 0,
#       saveState: 21,
#       restoreState: 21,
#       isEOF: 1,
#       direction: 'forward',
#       docsExamined: 21349
#     }
#   },
#   command: {
#     find: 'movies',
#     filter: { 'imdb.rating': 6 },
#     '$db': 'sample_mflix'
#   },
#   serverInfo: {
#     host: 'ac-lti9mog-shard-00-02.0epnrpd.mongodb.net',
#     port: 27017,
#     version: '7.0.8',
#     gitVersion: 'c5d33e55ba38d98e2f48765ec4e55338d67a4a64'
#   },
#   serverParameters: {
#     internalQueryFacetBufferSizeBytes: 104857600,
#     internalQueryFacetMaxOutputDocSizeBytes: 104857600,
#     internalLookupStageIntermediateDocumentMaxSizeBytes: 16793600,
#     internalDocumentSourceGroupMaxMemoryBytes: 104857600,
#     internalQueryMaxBlockingSortMemoryUsageBytes: 33554432,
#     internalQueryProhibitBlockingMergeOnMongoS: 0,
#     internalQueryMaxAddToSetBytes: 104857600,
#     internalDocumentSourceSetWindowFieldsMaxMemoryBytes: 104857600,
#     internalQueryFrameworkControl: 'trySbeRestricted'
#   },
#   ok: 1,
#   '$clusterTime': {
#     clusterTime: Timestamp({ t: 1712775433, i: 27 }),
#     signature: {
#       hash: Binary.createFromBase64('ubJrT9MIwye/omRMxo3b0we5IbQ=', 0),
#       keyId: Long('7297225448235204610')
#     }
#   },
#   operationTime: Timestamp({ t: 1712775433, i: 27 })
# }

# %%
createString = "db.movies.createIndex({'imdb.rating':1})"
idxString = "db.movies.find({'imdb.rating':6}).explain('executionStats')"

print(idxString.replace("\\", ""))
print("")

# !mongosh {mongoDB_connection_string} --quiet  --username {mongoDB_username} -p {mongoDB_password} \
--eval "use sample_mflix" \
--eval """{createString}""" \
--eval """{idxString}"""
# Out:
# db.movies.find({'imdb.rating':6}).explain('executionStats')
#
#  {
#   explainVersion: '1',
#   queryPlanner: {
#     namespace: 'sample_mflix.movies',
#     indexFilterSet: false,
#     parsedQuery: { 'imdb.rating': { '$eq': 6 } },
#     queryHash: 'B8C7FF17',
#     planCacheKey: 'A9BA69E3',
#     maxIndexedOrSolutionsReached: false,
#     maxIndexedAndSolutionsReached: false,
#     maxScansToExplodeReached: false,
#     winningPlan: {
#       stage: 'FETCH',
#       inputStage: {
#         stage: 'IXSCAN',
#         keyPattern: { 'imdb.rating': 1 },
#         indexName: 'imdb.rating_1',
#         isMultiKey: false,
#         multiKeyPaths: { 'imdb.rating': [] },
#         isUnique: false,
#         isSparse: false,
#         isPartial: false,
#         indexVersion: 2,
#         direction: 'forward',
#         indexBounds: { 'imdb.rating': [ '[6, 6]' ] }
#       }
#     },
#     rejectedPlans: []
#   },
#   executionStats: {
#     executionSuccess: true,
#     nReturned: 521,
#     executionTimeMillis: 2,
#     totalKeysExamined: 521,
#     totalDocsExamined: 521,
#     executionStages: {
#       stage: 'FETCH',
#       nReturned: 521,
#       executionTimeMillisEstimate: 0,
#       works: 522,
#       advanced: 521,
#       needTime: 0,
#       needYield: 0,
#       saveState: 0,
#       restoreState: 0,
#       isEOF: 1,
#       docsExamined: 521,
#       alreadyHasObj: 0,
#       inputStage: {
#         stage: 'IXSCAN',
#         nReturned: 521,
#         executionTimeMillisEstimate: 0,
#         works: 522,
#         advanced: 521,
#         needTime: 0,
#         needYield: 0,
#         saveState: 0,
#         restoreState: 0,
#         isEOF: 1,
#         keyPattern: { 'imdb.rating': 1 },
#         indexName: 'imdb.rating_1',
#         isMultiKey: false,
#         multiKeyPaths: { 'imdb.rating': [] },
#         isUnique: false,
#         isSparse: false,
#         isPartial: false,
#         indexVersion: 2,
#         direction: 'forward',
#         indexBounds: { 'imdb.rating': [ '[6, 6]' ] },
#         keysExamined: 521,
#         seeks: 1,
#         dupsTested: 0,
#         dupsDropped: 0
#       }
#     }
#   },
#   command: {
#     find: 'movies',
#     filter: { 'imdb.rating': 6 },
#     '$db': 'sample_mflix'
#   },
#   serverInfo: {
#     host: 'ac-lti9mog-shard-00-02.0epnrpd.mongodb.net',
#     port: 27017,
#     version: '7.0.8',
#     gitVersion: 'c5d33e55ba38d98e2f48765ec4e55338d67a4a64'
#   },
#   serverParameters: {
#     internalQueryFacetBufferSizeBytes: 104857600,
#     internalQueryFacetMaxOutputDocSizeBytes: 104857600,
#     internalLookupStageIntermediateDocumentMaxSizeBytes: 16793600,
#     internalDocumentSourceGroupMaxMemoryBytes: 104857600,
#     internalQueryMaxBlockingSortMemoryUsageBytes: 33554432,
#     internalQueryProhibitBlockingMergeOnMongoS: 0,
#     internalQueryMaxAddToSetBytes: 104857600,
#     internalDocumentSourceSetWindowFieldsMaxMemoryBytes: 104857600,
#     internalQueryFrameworkControl: 'trySbeRestricted'
#   },
#   ok: 1,
#   '$clusterTime': {
#     clusterTime: Timestamp({ t: 1712775439, i: 37 }),
#     signature: {
#       hash: Binary.createFromBase64('9rJyY/QvO/P5rJYke1e/mN3puLA=', 0),
#       keyId: Long('7297225448235204610')
#     }
#   },
#   operationTime: Timestamp({ t: 1712775439, i: 37 })
# }

# %% [markdown]
# ### Compound Indexes
#
# The most complex queries and the most performant application requirements typically take advantage of indexes on multiple fields, called "compound indexes"
#
# The best way to think about a compound index is like a phonebook. Or, more like a phonebook is essentially indexed on `{lastName:1,firstName:1}`
#
# ![Phonebook](./_images/3/phonebook.png)

# %% [markdown]
# {last_name:1,first_name:1,address:1}
#
# Thinking about questions that we can efficiently answer with this phonebook is a great metaphor for use of compound indexes
#
# Questions this book could easily answer:
# - What is Paul Bates's address and telephone number? `db.people.find({lastName:"Bates",firstName:"Paul"})`
# - How many Bates are there? `db.people.countDocuments({lastName:"Bates"})`
# - Organize (sort) all the Bates by first name. `db.people.find({lastName:"Bates"}).sort({firstName:1})`
#
# Questions that would be challenging:
# - what is the number of the person who lives on 119 Willow Road? `db.people.find({addr:"119 Willow Rd"})`
# - How many Charlottes are there? `db.people.countDocuments({firstName:"Charlotte"})`
# - Sort this phonebook by first name, not last name `db.people.find().sort({firstName:1})`
#
# This metaphor illustrates a concept called the **Index Prefix**
#
# Basically, for compound indexes, you can cover sorts and searches that take advantages of all fields moving from left to right.
#
# Given the index `{a:1,b:1,c:1}`, we could cover:
# - `db.collection.find({a:"example"})`
# - `db.collection.find({a:"example"}).sort({b:1})`
# - `db.collection.find({a:"example"}).sort({b:1,c:1})` <-- compound sort
# - `db.collection.find({a:"example",b:"example"})`
# - `db.collection.find({a:"example",b:"example"}).sort({b:1})`
# - `db.collection.find({a:"example",b:"example"}).sort({c:1})`
# - `db.collection.find({a:"example",b:"example"}).sort({b:1,c:1})`
# - `db.collection.find({a:"example",b:"example",c:"example"})`
#
# Note that we assume equality matches for the above examples. Range queries don't follow the same rules.
#
# ESR rule of thumb: It is generally a better index strategy to index fields in the order of equality, sort, range.
#
# compound sorts must follow the same relative directions as the index. For example with the same `abc` index, we could cover sorts on `{a:1,b:1,c:1}` or `{a:-1,b:-1,c:-1}` but **not** `{a:1,b:-1,c:1}` for instance.
#
# An implication of index prefixes is that indexes can be redundant. For example, given a collection with an index on `{a:1,b:1,c:1}`, the index `{a:1,b:1}` provides no value.
#
# ### Search Indexes + Aggregations
#
# Everything that we have discussed so far has been a feature of the core MongoDB server (mongod). However, There is one part of the Developer Exam that is only applicable to Atlas, the MongoDB DBaaS. That is Atlas Search Indexes. **These are seperate from the MongoDB indexes we have been discussing**. These indexes are hosted on a Lucene process outside of of the database.
#
# The way to define indexes is the via the Atlas UI or API, and the index definition is completely different from the syntax as shown previously in this session.
#
# **Index Definition**
#
# In order to configure a search index, one must use the Atlas UI, or Atlas admin API, or the MongoDB drivers.
#
# Generally the index definition has the following form:
# ```
# {
#   "name": "<index-name>",
#   "analyzer": "<analyzer-for-index>",
#   "searchAnalyzer": "<analyzer-for-query>",
#   "mappings": {
#     "dynamic": <boolean>,
#     "fields": { <field-definition> }
#   },
#   "analyzers": [ <custom-analyzer> ],
#   "storedSource": <boolean> | {
#     <stored-source-definition>
#   },
#   "synonyms": [
#   ...
#   ]
# }
# ```
# Although some of these configurations are outside the scope of the session, giving a search index a name, analyzer and mappings might come up on the developer exam. How do we _use_ this index? I won't make you wait for the answer.
#
# It's the aggregation framework. Specifically the `$search` stage. Let's take a look (using an index called "default"):

# %%
aggString = "db.movies.aggregate([{\\$search:{index:'default',text:{query:'piza',path:'title',fuzzy:{maxEdits:2}}}}])"

print(aggString.replace("\\", ""))
print("")

# !mongosh {mongoDB_connection_string} --quiet  --username {mongoDB_username} -p {mongoDB_password} \
--eval "use sample_mflix" \
--eval """{aggString}"""
# Out:
# db.movies.aggregate([{$search:{index:'default',text:{query:'piza',path:'title',fuzzy:{maxEdits:2}}}}])
#
#  [
#   {
#     _id: ObjectId('573a13c7f29313caabd73b2d'),
#     plot: 'A tribute to the late German choreographer, Pina Bausch, as her dancers perform her most famous creations.',
#     genres: [ 'Documentary' ],
#     runtime: 103,
#     metacritic: 83,
#     rated: 'PG',
#     cast: [
#       'Regina Advento',
#       'Malou Airaudo',
#       'Ruth Amarante',
#       'Jorge Puerta'
#     ],
#     poster: 'https://m.media-amazon.com/images/M/MV5BMTMyMTI1NDA5MV5BMl5BanBnXkFtZTcwNzM1NTY5Ng@@._V1_SY1000_SX677_AL_.jpg',
#     title: 'Pina',
#     fullplot: 'In modern dance since the 1970s, few choreographers have had more influence in the medium than the late Pina Bausch. This film explores the life and work of this artist of movement while we see her company perform her most notable creations where basic things like water, dirt and even gravity take on otherworldly qualities in their dancing.',
#     languages: [
#       'German',     'French',
#       'English',    'Spanish',
#       'Croatian',   'Italian',
#       'Portuguese', 'Russian',
#       'Korean'
#     ],
#     released: ISODate('2011-02-24T00:00:00.000Z'),
#     directors: [ 'Wim Wenders' ],
#     writers: [ 'Wim Wenders' ],
#     awards: {
#       wins: 12,
#       nominations: 20,
#       text: 'Nominated for 1 Oscar. Another 11 wins & 20 nominations.'
#     },
#     lastupdated: '2015-08-19 00:30:55.907000000',
#     year: 2011,
#     imdb: { rating: 7.7, votes: 10536, id: 1440266 },
#     countries: [ 'Germany', 'France', 'UK' ],
#     type: 'movie',
#     tomatoes: {
#       website: 'http://www.pina-film.de/',
#       viewer: { rating: 4, numReviews: 8256, meter: 81 },
#       dvd: ISODate('2013-01-22T00:00:00.000Z'),
#       critic: { rating: 8.3, numReviews: 93, meter: 95 },
#       boxOffice: '$3.5M',
#       consensus: 'Pina is an immersive, gorgeously shot tribute to the people who express life through movement.',
#       rotten: 5,
#       production: 'IFC Films',
#       lastUpdated: ISODate('2015-09-14T18:56:28.000Z'),
#       fresh: 88
#     },
#     num_mflix_comments: 0
#   },
#   {
#     _id: ObjectId('573a13a3f29313caabd0ed27'),
#     plot: "In 1993 Fiza's brother disappears during the riots in Mumbai. In 1999 Fiza is tired of waiting and goes looking for him.",
#     genres: [ 'Drama', 'Romance' ],
#     runtime: 170,
#     cast: [ 'Jaya Bhaduri', 'Karisma Kapoor', 'Hrithik Roshan', 'Neha' ],
#     poster: 'https://m.media-amazon.com/images/M/MV5BMDk4YjE4NmYtZTE0Mi00N2IwLTlhZmUtZDMzOWJjMzJiZmEzXkEyXkFqcGdeQXVyOTA0NTIzNzU@._V1_SY1000_SX677_AL_.jpg',
#     title: 'Fiza',
#     fullplot: `Six years after Fiza's (Karisma Kapoor) brother, Aman (played by Hrithik Roshan) disappears during the 1993 Mumbai riots, she goes to look for him. When she does find him, to her horror she sees that he has joined a terrorist group. She forces him to come home, and he finally re-unites with their mother (played by Jaya Bachchan). However his allegiance and thoughts make him want to join the terrorist network, led by Murad Khan (Manoj Bajpai). A confrontation with two men who harass Fiza leads to Aman revealing his involvement with the terrorist network in front of his sister, mother and the police. His mother's grief and disappointment eventually lead her to commit suicide. Fiza tries once more to find her brother, with the help of Anirudh (Bikram Saluja). Aman has been sent on a mission to kill two powerful politicians; when he does succeed in assassinating them, his own terrorist group tries to kill him. He escapes and Fiza follows him. They confront each other and with the police closing in on him, he asks her to kill him. After much persuasion Fiza kills her brother. Aman dies saying the first Kalma in Islam, "La illa ha ill Allah, Mohammad dur Rasullalah"`,
#     languages: [ 'Hindi', 'Urdu' ],
#     released: ISODate('2000-09-08T00:00:00.000Z'),
#     directors: [ 'Khalid Mohamed' ],
#     writers: [ 'Khalid Mohamed (story)', 'Javed Siddiqui (dialogue)' ],
#     awards: { wins: 4, nominations: 18, text: '4 wins & 18 nominations.' },
#     lastupdated: '2015-08-22 01:03:10.250000000',
#     year: 2000,
#     imdb: { rating: 6.2, votes: 2478, id: 248012 },
#     countries: [ 'India' ],
#     type: 'movie',
#     tomatoes: {
#       viewer: { rating: 3.4, numReviews: 2665, meter: 59 },
#       dvd: ISODate('2000-10-03T00:00:00.000Z'),
#       lastUpdated: ISODate('2015-09-01T19:40:22.000Z')
#     },
#     num_mflix_comments: 0
#   },
#   {
#     _id: ObjectId('573a13aef29313caabd2d288'),
#     plot: 'A pizza deliveryman develops a bond with a girl nearly half his age.',
#     genres: [ 'Comedy' ],
#     runtime: 80,
#     metacritic: 42,
#     cast: [
#       'Ethan Embry',
#       'Kylie Sparks',
#       'Julie Hagerty',
#       'Martin Campetta'
#     ],
#     num_mflix_comments: 0,
#     poster: 'https://m.media-amazon.com/images/M/MV5BMTkyMjU3MzgyMF5BMl5BanBnXkFtZTgwNjMyOTkwMzE@._V1_SY1000_SX677_AL_.jpg',
#     title: 'Pizza',
#     fullplot: "A long night's journey into day. On the eve of her 18th birthday, talkative and rotund Cara is invited to accompany a pizza delivery guy, Matt, on his rounds. It's a night of firsts for her - first job, first beer, first cigarette, first dance. How will she handle it? And, what about Matt - good-looking, single, unattached, and 30? Why would he want to include Cara? She's intrusive and vulnerable; he's under-employed and protective. Is there life after pizza?",
#     languages: [ 'English' ],
#     released: ISODate('2005-05-27T00:00:00.000Z'),
#     directors: [ 'Mark Christopher' ],
#     writers: [ 'Mark Christopher' ],
#     awards: { wins: 1, nominations: 0, text: '1 win.' },
#     lastupdated: '2015-09-01 00:04:46.787000000',
#     year: 2005,
#     imdb: { rating: 5.8, votes: 976, id: 376827 },
#     countries: [ 'USA' ],
#     type: 'movie'
#   },
#   {
#     _id: ObjectId('573a13dff29313caabdb8772'),
#     plot: 'A pizza delivery boy lands in a mysterious circumstance and it works a dramatic change in his life.',
#     genres: [ 'Horror', 'Romance', 'Thriller' ],
#     runtime: 127,
#     cast: [
#       'Vijay Sethupathi',
#       'Ramya Nambeeshan',
#       'Aadukalam Naren',
#       'Karunakaran'
#     ],
#     poster: 'https://m.media-amazon.com/images/M/MV5BNDc3MTM0ZDItZjcwMy00MmI5LTlhMTctYmQ4NjM1MDM5MTRlXkEyXkFqcGdeQXVyODk1MzE5NDA@._V1_SY1000_SX677_AL_.jpg',
#     title: 'Pizza',
#     fullplot: 'Michael (Vijay Sethupathi) lives with girlfriend Anu (Ramya Nambeeshan) and works as a deliveryman at a pizzeria. One day, Anu announces that she is pregnant and he is faced with a dilemma. They decide to marry and save up for a big bash later. But during a routine delivery one day, the pizza crumbles...',
#     languages: [ 'Tamil' ],
#     released: ISODate('2012-10-19T00:00:00.000Z'),
#     directors: [ 'Karthik Subbaraj' ],
#     awards: { wins: 2, nominations: 3, text: '2 wins & 3 nominations.' },
#     lastupdated: '2015-08-19 00:22:23.453000000',
#     year: 2012,
#     imdb: { rating: 8.1, votes: 2373, id: 2585562 },
#     countries: [ 'India' ],
#     type: 'movie',
#     tomatoes: {
#       viewer: { rating: 3.8, numReviews: 59, meter: 75 },
#       production: 'UTV Communications',
#       lastUpdated: ISODate('2015-09-01T19:35:56.000Z')
#     },
#     num_mflix_comments: 0
#   },
#   {
#     _id: ObjectId('573a1398f29313caabceb07c'),
#     plot: 'Three teenage girls come of age while working at a pizza parlor in the Connecticut town of Mystic.',
#     genres: [ 'Comedy', 'Drama', 'Romance' ],
#     runtime: 104,
#     metacritic: 60,
#     rated: 'R',
#     cast: [
#       'Annabeth Gish',
#       'Julia Roberts',
#       'Lili Taylor',
#       "Vincent D'Onofrio"
#     ],
#     poster: 'https://m.media-amazon.com/images/M/MV5BMTU1NDk1MTkzMF5BMl5BanBnXkFtZTcwMzY0MDQ1NA@@._V1_SY1000_SX677_AL_.jpg',
#     title: 'Mystic Pizza',
#     fullplot: 'Sisters Kat and Daisy work along with Jojo at the pizza parlour in Mystic, Connecticut. Kat, shortly off to Yale, finds herself drawn to a local architect she is babysitting for, while her more tearaway sister starts dating a guy from the money side of the tracks. Jojo leaves her man at the altar; she loves him but shies away from commitment. Meanwhile the fame of the pizza continues to spread; it seems to contain something almost ..... mystic.',
#     languages: [ 'English' ],
#     released: ISODate('1988-10-21T00:00:00.000Z'),
#     directors: [ 'Donald Petrie' ],
#     writers: [
#       'Amy Holden Jones (story)',
#       'Amy Holden Jones (screenplay)',
#       'Perry Howze (screenplay)',
#       'Randy Howze (screenplay)',
#       'Alfred Uhry (screenplay)'
#     ],
#     awards: { wins: 1, nominations: 4, text: '1 win & 4 nominations.' },
#     lastupdated: '2015-09-16 03:42:39.057000000',
#     year: 1988,
#     imdb: { rating: 6.2, votes: 16814, id: 95690 },
#     countries: [ 'USA' ],
#     type: 'movie',
#     tomatoes: {
#       viewer: { rating: 3.3, numReviews: 175836, meter: 84 },
#       dvd: ISODate('2000-08-15T00:00:00.000Z'),
#       critic: { rating: 7.3, numReviews: 51, meter: 86 },
#       lastUpdated: ISODate('2015-08-18T18:09:48.000Z'),
#       consensus: 'The Naked Gun is chock full of gags that are goofy, unapologetically crass, and ultimately hilarious.',
#       rotten: 7,
#       production: 'Paramount Pictures',
#       fresh: 44
#     },
#     num_mflix_comments: 0
#   },
#   {
#     _id: ObjectId('573a13a6f29313caabd17015'),
#     plot: 'Following the unexplained suicide of his wife Liza, a web designer turns to gasoline fumes and remote-control airplanes while avoiding an inevitable conflict with his mother-in-law.',
#     genres: [ 'Comedy', 'Drama' ],
#     runtime: 90,
#     metacritic: 58,
#     rated: 'R',
#     cast: [
#       'Philip Seymour Hoffman',
#       'J.D. Walsh',
#       'Jimmy Raskin',
#       'Kathy Bates'
#     ],
#     poster: 'https://m.media-amazon.com/images/M/MV5BMTI5NTYxNTEzNV5BMl5BanBnXkFtZTYwNjY3MTg5._V1_SY1000_SX677_AL_.jpg',
#     title: 'Love Liza',
#     fullplot: "Wilson Joel is a man in trouble. There's a searing pain in his gut that he can't tolerate and a dazed quietness to his struggle as he tries to maintain his equilibrium. Wilson is attempting to move on from the sudden and inexplicable suicide of his wife. His mother-in-law is there for him, but her sympathies turn quickly. He has an employer that seems to want to help him, and a workmate who wants him for herself. But nothing and no one can give Wilson solace; so, he seeks oblivion. It is not the usual alcohol or drugs. Wilson inhales fumes from gasoline cans and model airplane fuel and finds temporary salvation in the company of remote-control model enthusiasts. However, nothing that provides him relief really lasts.",
#     languages: [ 'English' ],
#     released: ISODate('2003-01-31T00:00:00.000Z'),
#     directors: [ 'Todd Louiso' ],
#     writers: [ 'Gordy Hoffman (screenplay)' ],
#     awards: { wins: 2, nominations: 3, text: '2 wins & 3 nominations.' },
#     lastupdated: '2015-08-28 00:17:26.360000000',
#     year: 2002,
#     imdb: { rating: 7, votes: 6082, id: 282698 },
#     countries: [ 'France', 'Germany', 'USA' ],
#     type: 'movie',
#     tomatoes: {
#       website: 'http://www.lovelizathemovie.com/',
#       viewer: { rating: 3.6, numReviews: 7081, meter: 77 },
#       dvd: ISODate('2003-05-27T00:00:00.000Z'),
#       critic: { rating: 5.9, numReviews: 85, meter: 53 },
#       lastUpdated: ISODate('2015-08-24T19:05:05.000Z'),
#       consensus: "Hoffman's performance is strong, but the lack of character development and story arc makes Love Liza unsatisfying.",
#       rotten: 40,
#       production: 'Sony Pictures Classics',
#       fresh: 45
#     },
#     num_mflix_comments: 0
#   },
#   {
#     _id: ObjectId('573a1399f29313caabcec0e0'),
#     plot: "Fourteen year-old Lisa is raised by her unmarried mother Katherine who overprotects her by forbidding her to date until she's sixteen. In despair, Lisa and schoolmate Wendy make up a game ...",
#     genres: [ 'Drama', 'Horror', 'Thriller' ],
#     runtime: 95,
#     rated: 'PG-13',
#     cast: [ 'Staci Keanan', 'Cheryl Ladd', 'D.W. Moffett', 'Tanya Fenmore' ],
#     num_mflix_comments: 0,
#     poster: 'https://m.media-amazon.com/images/M/MV5BOWE5M2I1NjUtOWQ1ZS00MmZjLWEyMjMtMWU2NTgxNWYzM2ZmXkEyXkFqcGdeQXVyMTQxNzMzNDI@._V1_SY1000_SX677_AL_.jpg',
#     title: 'Lisa',
#     fullplot: "Fourteen year-old Lisa is raised by her unmarried mother Katherine who overprotects her by forbidding her to date until she's sixteen. In despair, Lisa and schoolmate Wendy make up a game that consists of inferring attractive men's phone numbers from their car ID and giving them anonymous calls. Last victim is the handsome Richard, with whom Lisa begins a passionate phone relationship, unaware that he's also a psycho-killer and sex maniac...",
#     languages: [ 'English' ],
#     released: ISODate('1990-04-20T00:00:00.000Z'),
#     directors: [ 'Gary Sherman' ],
#     writers: [ 'Gary Sherman', 'Karen Clark' ],
#     awards: { wins: 0, nominations: 2, text: '2 nominations.' },
#     lastupdated: '2015-09-06 00:04:15.277000000',
#     year: 1990,
#     imdb: { rating: 5.9, votes: 963, id: 100031 },
#     countries: [ 'USA' ],
#     type: 'movie',
#     tomatoes: {
#       viewer: { rating: 3.2, numReviews: 120, meter: 49 },
#       production: 'United Artists',
#       lastUpdated: ISODate('2015-09-14T18:12:51.000Z')
#     }
#   },
#   {
#     _id: ObjectId('573a1399f29313caabced468'),
#     plot: 'In good old days Franz Maurer and his partners from secret police used to live like kings. Now, they all must adapt to new post-communist environment where they are scorned and losing all ...',
#     genres: [ 'Action', 'Crime', 'Drama' ],
#     runtime: 104,
#     cast: [
#       'Boguslaw Linda',
#       'Marek Kondrat',
#       'Cezary Pazura',
#       'Janusz Gajos'
#     ],
#     num_mflix_comments: 0,
#     poster: 'https://m.media-amazon.com/images/M/MV5BZGQwODdkOTctYWRlNC00ZjcyLWE4ZjctODQxZGVlM2YyMzViXkEyXkFqcGdeQXVyMjMwOTA0Ng@@._V1_SY1000_SX677_AL_.jpg',
#     title: 'Pigs',
#     fullplot: 'In good old days Franz Maurer and his partners from secret police used to live like kings. Now, they all must adapt to new post-communist environment where they are scorned and losing all the privileges. Some, like Franz, are like ordinary police fighting against drug dealers. But Franz would soon find that some of his friends are on the other side.',
#     languages: [ 'Polish', 'English', 'German', 'Russian' ],
#     released: ISODate('1992-11-20T00:00:00.000Z'),
#     directors: [ 'Wladyslaw Pasikowski' ],
#     writers: [ 'Wladyslaw Pasikowski' ],
#     awards: { wins: 5, nominations: 0, text: '5 wins.' },
#     lastupdated: '2015-05-02 01:55:11.073000000',
#     year: 1992,
#     imdb: { rating: 7.8, votes: 2026, id: 105185 },
#     countries: [ 'Poland' ],
#     type: 'movie',
#     tomatoes: {
#       viewer: { rating: 4, numReviews: 262, meter: 81 },
#       lastUpdated: ISODate('2015-08-01T18:04:32.000Z')
#     }
#   },
#   {
#     _id: ObjectId('573a13def29313caabdb6f31'),
#     countries: [ 'Latvia' ],
#     genres: [ 'Drama' ],
#     runtime: 63,
#     cast: [ 'Pauls Iklavs', 'Reinis Stabins' ],
#     num_mflix_comments: 1,
#     title: 'Picas',
#     lastupdated: '2015-05-16 01:36:47.463000000',
#     languages: [ 'Latvian' ],
#     released: ISODate('2012-11-11T00:00:00.000Z'),
#     directors: [ 'Laila Pakalnina' ],
#     writers: [ 'Laila Pakalnina' ],
#     awards: { wins: 1, nominations: 1, text: '1 win & 1 nomination.' },
#     year: 2012,
#     imdb: { rating: 6.2, votes: 21, id: 2536316 },
#     type: 'movie',
#     tomatoes: {
#       viewer: { rating: 2, numReviews: 1 },
#       lastUpdated: ISODate('2014-11-07T19:01:09.000Z')
#     }
#   },
#   {
#     _id: ObjectId('573a1396f29313caabce4622'),
#     plot: 'The story of a small and conservative West-Flemish village opposing the construction of a bridge over the Scheldt.',
#     genres: [ 'Drama' ],
#     runtime: 95,
#     cast: [
#       'Willeke van Ammelrooy',
#       'Jan Decleir',
#       'Carlos van Lanckere',
#       'Luc Ponette'
#     ],
#     num_mflix_comments: 1,
#     poster: 'https://m.media-amazon.com/images/M/MV5BNjI0MzI3OTUxNF5BMl5BanBnXkFtZTcwNjUxMjA0MQ@@._V1_SY1000_SX677_AL_.jpg',
#     title: 'Mira',
#     fullplot: 'The story of a small and conservative West-Flemish village opposing the construction of a bridge over the Scheldt.',
#     languages: [ 'Dutch' ],
#     released: ISODate('1971-03-04T00:00:00.000Z'),
#     directors: [ 'Fons Rademakers' ],
#     writers: [ 'Hugo Claus', 'Magda Reypens', 'Stijn Streuvels (novel)' ],
#     awards: { wins: 0, nominations: 1, text: '1 nomination.' },
#     lastupdated: '2015-08-16 01:15:13.403000000',
#     year: 1971,
#     imdb: { rating: 6.6, votes: 244, id: 67436 },
#     countries: [ 'Belgium', 'Netherlands' ],
#     type: 'movie',
#     tomatoes: {
#       viewer: { rating: 3.7, numReviews: 1243, meter: 77 },
#       dvd: ISODate('2001-05-08T00:00:00.000Z'),
#       production: 'Criterion Collection',
#       lastUpdated: ISODate('2015-08-26T18:15:05.000Z')
#     }
#   },
#   {
#     _id: ObjectId('573a1397f29313caabce7e07'),
#     plot: 'Two tapes, two Parisian mob killers, one corrupt policeman, an opera fan, a teenage thief, and the coolest philosopher ever filmed. All these characters twist their way through an intricate and stylish French language thriller.',
#     genres: [ 'Thriller' ],
#     runtime: 117,
#     rated: 'R',
#     cast: [
#       'Wilhelmenia Fernandez',
#       'Frèdèric Andrèi',
#       'Richard Bohringer',
#       'Thuy An Luu'
#     ],
#     poster: 'https://m.media-amazon.com/images/M/MV5BNjRjOGNlMjYtZDVmOC00ODZlLWE3MDAtNzM2NmZjY2YwNDQ0XkEyXkFqcGdeQXVyMjQzMzQzODY@._V1_SY1000_SX677_AL_.jpg',
#     title: 'Diva',
#     fullplot: "A young opera-loving mailman, Jules, becomes inadvertently entangled in murder, when a young woman fleeing two mob hit men drops an incriminating cassette into his mailbag. Jules has just recently recorded opera star Cynthia Hawkins' latest concert, something of a coup as Hawkins refuses to make recordings of any kind. Soon Jules finds himself the target of the hit men, who want the voice recording, and also of another couple of ominous and mysterious agents.",
#     languages: [ 'French', 'English', 'Italian' ],
#     released: ISODate('1982-04-23T00:00:00.000Z'),
#     directors: [ 'Jean-Jacques Beineix' ],
#     writers: [
#       'Daniel Odier (novel)',
#       'Jean-Jacques Beineix (adaptation)',
#       'Jean Van Hamme (adaptation)',
#       'Jean-Jacques Beineix (dialogue)'
#     ],
#     awards: {
#       wins: 10,
#       nominations: 6,
#       text: 'Nominated for 1 BAFTA Film Award. Another 9 wins & 6 nominations.'
#     },
#     lastupdated: '2015-08-30 00:57:52.790000000',
#     year: 1981,
#     imdb: { rating: 7.3, votes: 8555, id: 82269 },
#     countries: [ 'France' ],
#     type: 'movie',
#     tomatoes: {
#       viewer: { rating: 4, numReviews: 6255, meter: 86 },
#       dvd: ISODate('1997-10-28T00:00:00.000Z'),
#       critic: { rating: 8.1, numReviews: 44, meter: 98 },
#       lastUpdated: ISODate('2015-09-14T21:03:16.000Z'),
#       consensus: 'Beineix combines unique cinematography, an intelligent script, and a brilliant soundtrack to make Diva a stylishly memorable film.',
#       rotten: 1,
#       production: 'Rialto Pictures',
#       fresh: 43
#     },
#     num_mflix_comments: 0
#   },
#   {
#     _id: ObjectId('573a13daf29313caabdac6d4'),
#     plot: 'A loan shark is forced to reconsider his violent lifestyle after the arrival of a mysterious woman claiming to be his long-lost mother.',
#     genres: [ 'Drama' ],
#     runtime: 104,
#     metacritic: 72,
#     cast: [ 'Min-soo Jo', 'Jung-Jin Lee', 'Ki-Hong Woo', 'Eunjin Kang' ],
#     num_mflix_comments: 1,
#     poster: 'https://m.media-amazon.com/images/M/MV5BODQ3Nzg1NjkyNl5BMl5BanBnXkFtZTcwMzEyOTQzOQ@@._V1_SY1000_SX677_AL_.jpg',
#     title: 'Pieta',
#     fullplot: 'A loan shark is forced to reconsider his violent lifestyle after the arrival of a mysterious woman claiming to be his long-lost mother.',
#     languages: [ 'Korean' ],
#     released: ISODate('2012-09-06T00:00:00.000Z'),
#     directors: [ 'Ki-duk Kim' ],
#     writers: [ 'Ki-duk Kim' ],
#     awards: { wins: 13, nominations: 17, text: '13 wins & 17 nominations.' },
#     lastupdated: '2015-08-19 00:08:37.877000000',
#     year: 2012,
#     imdb: { rating: 7.2, votes: 8016, id: 2299842 },
#     countries: [ 'South Korea' ],
#     type: 'movie',
#     tomatoes: {
#       website: 'http://drafthousefilms.com/film/pieta',
#       viewer: { rating: 3.6, numReviews: 3128, meter: 72 },
#       dvd: ISODate('2013-07-23T00:00:00.000Z'),
#       critic: { rating: 6.6, numReviews: 51, meter: 75 },
#       boxOffice: '$21.9k',
#       consensus: 'It lacks subtlety and depth of character, but Pieta gets by with committed performances and a darkly ambitious, deceptively simple message.',
#       rotten: 13,
#       production: 'Drafthouse Films',
#       lastUpdated: ISODate('2015-09-12T19:22:58.000Z'),
#       fresh: 38
#     }
#   },
#   {
#     _id: ObjectId('573a13abf29313caabd25551'),
#     plot: 'A cleaning woman decides to sue the state for illegal discharge.',
#     genres: [ 'Drama' ],
#     runtime: 94,
#     cast: [
#       'Sari Mèllinen',
#       'Ilkka Koivula',
#       'Hannes Suominen',
#       'Kristiina Halkola'
#     ],
#     num_mflix_comments: 1,
#     poster: 'https://m.media-amazon.com/images/M/MV5BODgwNTI2NTUzMV5BMl5BanBnXkFtZTcwOTUyMzMzMQ@@._V1_SY1000_SX677_AL_.jpg',
#     title: 'Eila',
#     fullplot: "Forty-something, divorced Eila works as a cleaner for the Finnish government. When the cleaning business is privatized, her colleagues go on strike against impending redundancies but end up settling their dispute on questionable terms. Eila is despised as scab until a lawyer helps her -- and hundreds of her colleagues around the country -- file a winning lawsuit against the Finnish State. Subplots include a gentle but clueless musician boyfriend and Eila's son, a juvenile delinquent just released from prison and trying to cope with his own problems. Based on true events in the 1990s when cleaning women of the former National Building Board sued the Finnish government for illegal discharges.",
#     languages: [ 'Finnish' ],
#     released: ISODate('2003-03-14T00:00:00.000Z'),
#     directors: [ 'Jarmo Lampela' ],
#     writers: [ 'Tove Idstrèm' ],
#     awards: { wins: 2, nominations: 7, text: '2 wins & 7 nominations.' },
#     lastupdated: '2015-08-21 01:03:51.890000000',
#     year: 2003,
#     imdb: { rating: 6.5, votes: 291, id: 343624 },
#     countries: [ 'Finland' ],
#     type: 'movie',
#     tomatoes: {
#       viewer: { rating: 4.3, numReviews: 222, meter: 86 },
#       dvd: ISODate('2002-01-01T00:00:00.000Z'),
#       lastUpdated: ISODate('2015-05-03T18:45:33.000Z')
#     }
#   },
#   {
#     _id: ObjectId('573a1399f29313caabced23c'),
#     plot: "Shoko and Mutsuki get married to satisfy their worried parents, but she is well past the age at which a 'good' Japanese woman should marry, and he is in love with a young male college ...",
#     genres: [ 'Comedy', 'Drama', 'Romance' ],
#     runtime: 98,
#     cast: [
#       'Hiroko Yakushimaru',
#       'Etsushi Toyokawa',
#       'Michitaka Tsutsui',
#       'Kai Atè'
#     ],
#     title: 'Kira kira hikaru',
#     fullplot: "Shoko and Mutsuki get married to satisfy their worried parents, but she is well past the age at which a 'good' Japanese woman should marry, and he is in love with a young male college student. The film is less a realistic exploration of gay life than a fairy tale of three young Japanese trying to construct an alternative to the sexual and familial roles given to them by a society turning increasingly emotionally barren.L.",
#     languages: [ 'Japanese' ],
#     released: ISODate('1993-07-11T00:00:00.000Z'),
#     directors: [ 'Joji Matsuoka' ],
#     writers: [ 'Kaori Eguni (novel)', 'Joji Matsuoka' ],
#     awards: { wins: 3, nominations: 0, text: '3 wins.' },
#     lastupdated: '2015-08-17 00:19:56.313000000',
#     year: 1992,
#     imdb: { rating: 7.1, votes: 84, id: 104616 },
#     countries: [ 'Japan' ],
#     type: 'movie',
#     tomatoes: {
#       viewer: { numReviews: 1, meter: 0 },
#       critic: { meter: 0 },
#       lastUpdated: ISODate('2012-10-01T00:00:00.000Z')
#     },
#     num_mflix_comments: 0
#   },
#   {
#     _id: ObjectId('573a139cf29313caabcf6b31'),
#     plot: "A couple of friends work for a taxi driver to rob his passengers, but they feel like they're getting ripped off. They decide to plan their own robberies, but they are amateurs and things ...",
#     genres: [ 'Crime', 'Drama' ],
#     runtime: 92,
#     rated: 'R',
#     cast: [
#       'Hèctor Anglada',
#       'Jorge Sesèn',
#       'Pamela Jordèn',
#       'Adrièn Yospe'
#     ],
#     title: 'Pizza, Beer, and Cigarettes',
#     fullplot: "A couple of friends work for a taxi driver to rob his passengers, but they feel like they're getting ripped off. They decide to plan their own robberies, but they are amateurs and things don't go too well. One of the youths, Cordoba, whose girlfriend Sandra is pregnant, just wants to get enough cash so they can leave Argentina and get to Uruguay to start a new life. He and his friends plan one last robbery, but things don't go as planned.",
#     languages: [ 'Spanish' ],
#     released: ISODate('1998-01-15T00:00:00.000Z'),
#     directors: [ 'Adrièn Caetano', 'Bruno Stagnaro' ],
#     writers: [ 'Adrièn Caetano', 'Bruno Stagnaro' ],
#     awards: { wins: 12, nominations: 4, text: '12 wins & 4 nominations.' },
#     lastupdated: '2015-08-30 00:51:09.400000000',
#     year: 1998,
#     imdb: { rating: 7.2, votes: 968, id: 145393 },
#     countries: [ 'Argentina' ],
#     type: 'movie',
#     tomatoes: {
#       viewer: { rating: 3.4, numReviews: 592, meter: 48 },
#       dvd: ISODate('2005-12-27T00:00:00.000Z'),
#       lastUpdated: ISODate('2015-08-20T19:07:19.000Z')
#     },
#     num_mflix_comments: 0
#   },
#   {
#     _id: ObjectId('573a13a4f29313caabd10c00'),
#     plot: `Liza Minnelli stars in a television concert directed and choreographed by Bob Fosse. She performs such songs as the title number, "Liza with a 'Z'" and "Son of a Preacher Man". The concert ...`,
#     genres: [ 'Music' ],
#     runtime: 55,
#     cast: [ 'Liza Minnelli' ],
#     num_mflix_comments: 0,
#     poster: 'https://m.media-amazon.com/images/M/MV5BNDcyNzQwMzIwMF5BMl5BanBnXkFtZTcwNDMyNzIzMQ@@._V1_SY1000_SX677_AL_.jpg',
#     title: 'Liza with a Z',
#     fullplot: `Liza Minnelli stars in a television concert directed and choreographed by Bob Fosse. She performs such songs as the title number, "Liza with a 'Z'" and "Son of a Preacher Man". The concert concludes with a medley of songs from the film Cabaret (1972).`,
#     languages: [ 'English' ],
#     released: ISODate('1972-09-10T00:00:00.000Z'),
#     directors: [ 'Bob Fosse' ],
#     writers: [ 'Fred Ebb' ],
#     awards: {
#       wins: 6,
#       nominations: 5,
#       text: 'Won 4 Primetime Emmys. Another 2 wins & 5 nominations.'
#     },
#     lastupdated: '2015-09-03 00:41:23.787000000',
#     year: 1972,
#     imdb: { rating: 8.3, votes: 437, id: 256153 },
#     countries: [ 'USA' ],
#     type: 'movie',
#     tomatoes: {
#       viewer: { rating: 4.1, numReviews: 88, meter: 86 },
#       dvd: ISODate('2006-04-04T00:00:00.000Z'),
#       production: 'Showtime Networks Inc.',
#       lastUpdated: ISODate('2015-08-14T18:43:12.000Z')
#     }
#   },
#   {
#     _id: ObjectId('573a13d8f29313caabda746a'),
#     plot: "Liza's a nurse, seeking love. Her only company is a long-dead Japanese pop star, who turns her into a fox-fairy out of jealousy. Now, every men who desires Liza shall die horribly. Can she overcome the curse?",
#     genres: [ 'Comedy', 'Fantasy', 'Romance' ],
#     runtime: 98,
#     cast: [
#       'Mènika Balsai',
#       'Szabolcs Bede Fazekas',
#       'David Sakurai',
#       'Zoltèn Schmied'
#     ],
#     num_mflix_comments: 0,
#     poster: 'https://m.media-amazon.com/images/M/MV5BZmQyYTdkNzMtYWVjMS00MWRmLTgzYjktZGY2NmY4OTZmMGExXkEyXkFqcGdeQXVyMTMxODk2OTU@._V1_SY1000_SX677_AL_.jpg',
#     title: 'Liza, the Fox-Fairy',
#     fullplot: "Liza's a nurse, seeking love. Her only company is a long-dead Japanese pop star, who turns her into a fox-fairy out of jealousy. Now, every men who desires Liza shall die horribly. Can she overcome the curse?",
#     languages: [ 'Hungarian', 'Japanese' ],
#     released: ISODate('2015-02-19T00:00:00.000Z'),
#     directors: [ 'Kèroly Ujj Mèszèros' ],
#     writers: [ 'Bèlint Hegedès', 'Kèroly Ujj Mèszèros' ],
#     awards: { wins: 9, nominations: 1, text: '9 wins & 1 nomination.' },
#     lastupdated: '2015-08-20 00:49:36.157000000',
#     year: 2015,
#     imdb: { rating: 8.2, votes: 1799, id: 2210769 },
#     countries: [ 'Hungary' ],
#     type: 'movie',
#     tomatoes: {
#       viewer: { rating: 4.2, numReviews: 14 },
#       lastUpdated: ISODate('2015-09-10T17:51:51.000Z')
#     }
#   },
#   {
#     _id: ObjectId('573a1398f29313caabcea103'),
#     plot: "George has just been released from prison, and manages to get a job driving a call girl from customer to customer. Initially they don't get on; he doesn't fit in with the high class customers Simone services. Will they ever get on?",
#     genres: [ 'Crime', 'Drama', 'Romance' ],
#     runtime: 104,
#     rated: 'R',
#     cast: [
#       'Bob Hoskins',
#       'Cathy Tyson',
#       'Michael Caine',
#       'Robbie Coltrane'
#     ],
#     num_mflix_comments: 1,
#     poster: 'https://m.media-amazon.com/images/M/MV5BODQyNTczZmEtYWIyMC00NGFjLTgwNTktM2JlNjZmZTVmNGFiXkEyXkFqcGdeQXVyMTAwMzUyOTc@._V1_SY1000_SX677_AL_.jpg',
#     title: 'Mona Lisa',
#     fullplot: "George, after getting out of prison, begins looking for a job, but his time in prison has reduced his stature in the criminal underworld. The only job he can find is to be a driver for Simone, a beautiful high-priced call girl, with whom he forms an at first grudging, and then real affection. Only Simone's playing a dangerous game, and when George agrees to help her, they both end up in a huge amount of trouble with Mortwell, the local kingpin.",
#     languages: [ 'English' ],
#     released: ISODate('1986-06-13T00:00:00.000Z'),
#     directors: [ 'Neil Jordan' ],
#     writers: [ 'Neil Jordan (screenplay)', 'David Leland (screenplay)' ],
#     awards: {
#       wins: 16,
#       nominations: 11,
#       text: 'Nominated for 1 Oscar. Another 15 wins & 11 nominations.'
#     },
#     lastupdated: '2015-09-06 00:55:12.150000000',
#     year: 1986,
#     imdb: { rating: 7.4, votes: 9560, id: 91538 },
#     countries: [ 'UK' ],
#     type: 'movie'
#   },
#   {
#     _id: ObjectId('573a1399f29313caabcee89f'),
#     plot: 'The film tells the story of two girls who are of totally different character. They know each other since their childhood and were friends until they became teenagers. But growing up and ...',
#     genres: [ 'Drama' ],
#     runtime: 128,
#     cast: [
#       'Romane Bohringer',
#       'Elsa Zylberstein',
#       'Florence Thomassin',
#       'Jean-Philippe ècoffey'
#     ],
#     poster: 'https://m.media-amazon.com/images/M/MV5BMTgzOTMxNTc3NV5BMl5BanBnXkFtZTcwOTE5MjcxMQ@@._V1_SY1000_SX677_AL_.jpg',
#     title: 'Mina Tannenbaum',
#     fullplot: 'The film tells the story of two girls who are of totally different character. They know each other since their childhood and were friends until they became teenagers. But growing up and becoming adults they go different ways.',
#     languages: [ 'French' ],
#     released: ISODate('1995-05-26T00:00:00.000Z'),
#     directors: [ 'Martine Dugowson' ],
#     writers: [ 'Martine Dugowson' ],
#     awards: { wins: 2, nominations: 2, text: '2 wins & 2 nominations.' },
#     lastupdated: '2015-08-12 00:03:50.220000000',
#     year: 1994,
#     imdb: { rating: 7.3, votes: 818, id: 110521 },
#     countries: [ 'Netherlands', 'France', 'Belgium' ],
#     type: 'movie',
#     tomatoes: {
#       viewer: { rating: 4.2, numReviews: 424, meter: 90 },
#       dvd: ISODate('1996-11-19T00:00:00.000Z'),
#       lastUpdated: ISODate('2015-04-28T19:40:02.000Z')
#     },
#     num_mflix_comments: 0
#   },
#   {
#     _id: ObjectId('573a13c9f29313caabd79ae5'),
#     plot: "Ceci, a seven year old girl, has to keep a huge secret, but she doesn't completely understand what is the secret about. The life of her family depends on her silence. But what exactly must ...",
#     genres: [ 'Drama' ],
#     runtime: 115,
#     cast: [
#       'Paula Galinelli Hertzog',
#       'Laura Agorreca',
#       'Viviana Suraniti',
#       'Sharon Herrera'
#     ],
#     num_mflix_comments: 0,
#     title: 'The Prize',
#     fullplot: "Ceci, a seven year old girl, has to keep a huge secret, but she doesn't completely understand what is the secret about. The life of her family depends on her silence. But what exactly must she keep silent about? Ceci and her mom live hidden from military repression in Argentina. Ceci asks herself: what must she say? What should she really believe and do in order to deserve the love of her mother and others?",
#     languages: [ 'Spanish' ],
#     released: ISODate('2012-01-27T00:00:00.000Z'),
#     directors: [ 'Paula Markovitch' ],
#     writers: [ 'Paula Markovitch (screenplay)' ],
#     awards: { wins: 13, nominations: 8, text: '13 wins & 8 nominations.' },
#     lastupdated: '2015-07-01 05:09:54.307000000',
#     year: 2011,
#     imdb: { rating: 6.6, votes: 251, id: 1525346 },
#     countries: [ 'Mexico', 'France', 'Poland', 'Germany' ],
#     type: 'movie',
#     tomatoes: {
#       viewer: { rating: 4, numReviews: 15 },
#       lastUpdated: ISODate('2015-09-11T18:20:57.000Z')
#     }
#   }
# ]
# Type "it" for more

# %% [markdown]
# Comment on Atlas UI:
# - data explorer and loading sample dataset might be included in dev certification exam as well
